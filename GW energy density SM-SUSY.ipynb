# %%
import numpy as np
import scipy.integrate as integrate
import warnings
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import array
from scipy.special import spherical_jn
from scipy.integrate import ode
from scipy.optimize import curve_fit

# %%
#Calculate the scale factor and its derivative for the SM
df_SM = pd.read_csv('dof_SM_SUSY2.csv')
s_df_SM = pd.read_csv('s_dof_SM_SUSY2.csv')

#Set constants
h = 0.7
#H0 = 100*h #km s^-1 Mpc^-1
H0 = h/(3.0857*10**17) #s−1
a0 = 1
om_r = 4.15*10**(-5)*h**(-2)
om_m = 1-om_r
om_gamma = 2.4728*10**(-5)*h**(-2)
om_nu = om_r-om_gamma
a_eq = om_r/om_m
F_nu_0 = 0.40523
g0 = df_SM['dof'][0]
gs0 = s_df_SM['s_dof'][0]
g_df_ = df_SM['dof']
gs_df_ = s_df_SM['s_dof']
temperature_ = df_SM['temperature']
T0 = 2.73*8.6173*10**(-11) #MeV
#Mpl = 1.2*10**22 #MeV
Mpl = 2.435*10**21 #MeV, use this one
G = 1/(8*np.pi*Mpl**2)


V_inf = (10**19)**4 #MeV
H_inf = np.sqrt(V_inf/(3*Mpl**2))
mpl = np.sqrt(8*np.pi)*Mpl
delta_prim2 = (16/np.pi)*(H_inf/mpl)**2
P_t = 2*V_inf/(3*np.pi**2*Mpl**4)

print(g_df_)
print(gs_df_)
# Out:
# 0         3.362644
# 1         3.362644
# 2         3.362644
# 3         3.362644
# 4         3.362644
#            ...
# 8075    223.874393
# 8076    223.874401
# 8077    223.874408
# 8078    223.874415
# 8079    223.874422
# Name: dof, Length: 8080, dtype: float64
# 0         3.909091
# 1         3.909091
# 2         3.909091
# 3         3.909091
# 4         3.909091
#            ...
# 8075    223.874393
# 8076    223.874401
# 8077    223.874408
# 8078    223.874415
# 8079    223.874422
# Name: s_dof, Length: 8080, dtype: float64

# %%
def find_duplicate_indices(arr):
    index_dict = {}
    duplicates = []

    for i, item in enumerate(arr):
        if item in index_dict:
            duplicates.append((index_dict[item], i))
        else:
            index_dict[item] = i

    return duplicates

# Example usage:
result = find_duplicate_indices(temperature_)
print("Duplicate indices:", result)
# Out:
# Duplicate indices: [(199, 200), (1699, 1700), (6579, 6580)]

# %%
#Remove duplicates of temperature and corresponding g and gs (they are next to each other)
print(len(temperature_))
print(len(np.unique(temperature_)))

#temperature_[np.where(temperature_==0.0001)]       
print(temperature_[np.where([temperature_==0.0001])[1]])
print(temperature_[np.where([temperature_==1.0])[1]])
print(temperature_[np.where([temperature_==1000000.0])[1]])
# Out:
# 8080
# 8077
# Series([], Name: temperature, dtype: float64)
# 1699    1.0
# 1700    1.0
# Name: temperature, dtype: float64
# 6579    1000000.0
# 6580    1000000.0
# Name: temperature, dtype: float64

# %%
index = [200,1700,6580]
temperature1 = np.delete(np.array(temperature_),index)
g1 = np.delete(np.array(g_df_),index)
gs1 = np.delete(np.array(gs_df_),index)
print(temperature1[0])
extra_temperatures = np.linspace(T0, temperature1[0],30)[0:-1]
print(T0)
print(extra_temperatures)
temperature = np.append(extra_temperatures, temperature1)
g0_ar = np.full(len(extra_temperatures), g0)
gs0_ar = np.full(len(extra_temperatures), gs0)
g_new = np.append(g0_ar, g1)
gs_new = np.append(gs0_ar, gs1)
# Out:
# 1e-09
# 2.3525229e-10
# [2.35252290e-10 2.61622901e-10 2.87993511e-10 3.14364122e-10
#  3.40734733e-10 3.67105343e-10 3.93475954e-10 4.19846565e-10
#  4.46217176e-10 4.72587786e-10 4.98958397e-10 5.25329008e-10
#  5.51699618e-10 5.78070229e-10 6.04440840e-10 6.30811450e-10
#  6.57182061e-10 6.83552672e-10 7.09923282e-10 7.36293893e-10
#  7.62664504e-10 7.89035114e-10 8.15405725e-10 8.41776336e-10
#  8.68146947e-10 8.94517557e-10 9.20888168e-10 9.47258779e-10
#  9.73629389e-10]

# %%
#Compute all k's
kc0 = 2*np.pi*a0*1.65*2*np.pi*10**(-7)*(T0/(10**3))*(gs0/100)**(-1/3)*(g0/100)**(1/2)
f_0 = 1.65*2*np.pi*10**(-7)*(temperature/(10**3))*(gs_new/100)**(-1/3)*(g_new/100)**(1/2)
k = f_0*2*np.pi*a0
print(k)
# Out:
# [8.27991840e-19 9.20805604e-19 1.01361937e-18 ... 7.35937384e+01
#  7.40473146e+01 7.45036862e+01]

# %%
#k_eq
T_eq =  ((gs0/gs0)**(1/3))*T0*a0/a_eq #MeV
g_eq = g0
gs_eq = gs0
k_eq = 2*np.pi*a0*1.65*2*np.pi*10**(-7)*(T_eq/(10**3))*(gs_eq/100)**(-1/3)*(g_eq/100)**(1/2)
print(T_eq)
print(k_eq)
# Out:
# 2.777442388673855e-06
# 9.775461202511588e-15

# %%
#Relate T to a:
a_T = ((gs0/gs_new)**(1/3))*T0*a0/temperature

plt.plot(temperature, a_T)
plt.xscale('log')
#plt.yscale('log')
plt.xlabel('T (MeV)')
plt.ylabel('a')
# Out:
# Text(0, 0.5, 'a')

# %%
#Make an array where a, g, gs are reversed
length = len(a_T)-1
print(length)
a_T_res = np.zeros(len(a_T))
g_res = np.zeros(len(a_T))
gs_res = np.zeros(len(a_T))
for i in np.arange(0,len(a_T)):
    a_T_res[i] = a_T[length-i]
    g_res[i] = g_new[length-i]
    gs_res[i] = gs_new[length-i]
    
print(a_T_res[0])
# Out:
# 8105
# 6.1032003053870154e-21

# %%
#Calculate a, tau, and a'
tau_and_a = np.zeros((len(a_T_res),2))
tau_and_a[0,0] = 0
tau_and_a[0,1] = 0

for i in np.arange(1,len(tau_and_a)):
    tau_and_a[i,0] = a_T_res[i]
    tau_and_a[i,1] = (tau_and_a[i,0]-tau_and_a[i-1,0])/(H0*a0**2*np.sqrt((g_res[i]/g0)*(gs_res[i]/gs0)**(-4/3)*om_r+om_m*a_T_res[i]/a0)) + tau_and_a[i-1,1]
    

dadtau = np.zeros(np.size(tau_and_a[:,0]))
for i in range(np.size(tau_and_a[:,0])):
    dadtau[i] = (tau_and_a[i,0] - tau_and_a[i-1,0])/(tau_and_a[i,1]-tau_and_a[i-1,1])

# %%
a = tau_and_a[:,0]
tau = tau_and_a[:,1]
aprime = dadtau
kc = k
g = g_new
gs = gs_new
print(gs)
# Out:
# [  3.90909091   3.90909091   3.90909091 ... 223.87440809 223.87441532
#  223.87442246]

# %%
plt.plot(temperature, g)
plt.xscale('log')
plt.yscale('log')

# %%
#Matter radiation equality
T_eq =  ((gs0/gs0)**(1/3))*T0*a0/a_eq #MeV
g_eq = g0
gs_eq = gs0
k_eq = 2*np.pi*a0*1.65*2*np.pi*10**(-7)*(T_eq/(10**3))*(gs_eq/100)**(-1/3)*(g_eq/100)**(1/2)
print(k_eq)
# Out:
# 9.775461202511588e-15

# %%
#Neutrino decoupling
T_dec =  2 #MeV
print('T_dec', temperature[1747], 'MeV')
gs_dec = gs[1747]
a_dec = ((gs0/gs_dec)**(1/3))*T0*a0/T_dec
print(a_dec)
print('a_dec', a[6358])
print('tau_dec', tau[6358])
tau_dec = tau[6358]

#tau_dec
value=tau[tau>=tau_dec][0]
print(value)
np.where([tau==value])[1][0]
print(tau[np.where([tau==value])[1][0]])
#The index is:
print(np.where([tau==value])[1][0])
# Out:
# T_dec 2.000000000000001 MeV
# 8.889969446874166e-11
# a_dec 8.889969446874162e-11
# tau_dec 4690781002.909309
# 4690781002.909309
# 4690781002.909309
# 6358

# %%
plt.plot(tau[100:-200], a[100:-200])
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\tau$ (s)')
plt.ylabel(r'$a(\tau)$')
plt.title(r'Evolution of $a(\tau)$')
plt.show()

plt.plot(tau[100:-200], aprime[100:-200])
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\tau$ (s)')
plt.ylabel(r'$da/d\tau$')
plt.title(r'Evolution of $da/d\tau$ SM')
plt.savefig('dadtau_SM_zoom.png', bbox_inches='tight')
plt.show()

plt.plot(tau, aprime)
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\tau$ (s)')
plt.ylabel(r'$da/d\tau$')
plt.title(r'Evolution of $da/d\tau$ SM')
plt.savefig('dadtau_SM_full.png', bbox_inches='tight')
plt.show()

# %%
#Divide k, g, gs etc in a matter part and radiation part

kc_list = kc[kc<=0.01]
kc_rad = kc_list[kc_list>=k_eq]
kc_matter = kc_list[kc_list<k_eq]
kc_matter_IDE = kc_matter[kc_matter>2*10**(-18)]
kc_matter_after_neutrino = kc_matter[kc_matter<5*10**(-18)]
kc_IDE = np.append(kc_matter, kc_rad)

#Get corresponding a, aprime


a_res = np.zeros(len(a))
time_res = np.zeros(len(tau))
aprime_res = np.zeros(len(aprime))
for i in np.arange(0,len(a)):
    a_res[i] = a[len(a)-1-i]
    time_res[i] = tau[len(tau)-1-i]
    aprime_res[i] = aprime[len(aprime)-1-i]


a_list = a_res[kc<=0.01]
a_rad = a_list[kc_list>=k_eq]
a_matter = a_list[kc_list<k_eq]
a_matter_IDE = a_matter[kc_matter>5*10**(-18)]
a_matter_after_neutrino = a_matter[kc_matter<5*10**(-18)]
a_IDE = np.append(a_matter_IDE, a_rad)

aprime_list = aprime_res[kc<=0.01]
aprime_rad = aprime_list[kc_list>=k_eq]

# %%
"""Calculate chi prime for radiation """

solution_Chiprime_rad = np.zeros((len(kc_rad), 2)) #contains for every k; k, chi'(u_hc)
list_A_rad = np.zeros((len(kc_rad), 2)) #contains for every k; k, A

#Calculate chi(u), chi'(u)
def Bessel(x):
    return spherical_jn(2, x)
    
# Define the second-order ODE
def odefunc(t, Y, p):
    y, v = Y
    dydt = v
    dvdt = -2*p*v - y
    return [dydt, dvdt]


def odefuncIntegral(t, Y, p, o, b):
    y, v = Y
    dydt = v
    dvdt = -2*p*v - y - 24*b*p**2*o
    return [dydt, dvdt]


WKB_Chi_Prime_0 = np.zeros(np.size(kc_rad))

F_nu = F_nu_0/(1+a/a_eq)
U_Neutrino = np.where([tau==tau_dec])[1][0] #gives the index of tau = tau_dec
solution_match = np.empty((len(kc_rad), 3)) #contains for every k; k, A, delta

for loop in range(0,len(kc_rad)):
    print(kc_rad[loop])
    u1 = kc_rad[loop]*tau
    u = u1[u1<=2000]

    aprime_over_a = 1/kc_rad[loop]*(aprime/a)
    solution = []
    # Initial conditions
    chi_u_begin = 1
    dchi_du_begin = 0

    # Create an ODE solver
    solver_chi = ode(odefunc)
    solver_chi.set_integrator('dop853',nsteps=100000)  # You can choose a different method if needed
    #nsteps for e-14 up to one before 2.1566028854025033e-06 = 100000
    #that is kc_rad[4295], ,nsteps=10**8

    # Set initial conditions
    solver_chi.set_initial_value([chi_u_begin, dchi_du_begin], t=0)
    
    # Solve the ODE
    q = 1
    solution.append([u[0], chi_u_begin, dchi_du_begin])
    while solver_chi.successful() and solver_chi.t < u[-1] and q<len(u):
        solver_chi.set_f_params(aprime_over_a[q]) 
        solver_chi.integrate(u[q])
        solution.append([solver_chi.t, *solver_chi.y]) #contains time, chi, deriv of chi

        if not solver_chi.successful():
            print('error1', q)
        q+=1

    # Extract the results
    solution = np.array(solution)
    print('First Solution done')
    
    """Perform the IDE"""
    
    #calculate the integral
    U_List = solution[:,0]
    Chi_Prime_List = solution[:,2]
    U_Size = np.size(solution[:,0])
    Integrant = np.zeros([U_Size,U_Size])

    Integral = np.zeros(U_Size)
    for i in range(U_Neutrino,U_Size):
        for j in range(U_Neutrino,i): 
            Integrant[i,j] = (U_List[j]-U_List[j-1])*Chi_Prime_List[j]*Bessel(U_List[i]-U_List[j])/((U_List[i]-U_List[j])**2)
        #print(i,U_Size)
    Integral = np.array(np.diag(np.cumsum(Integrant,axis = 1)))
    print('Integral Done')
    

    solution_Int = []

    # Create an ODE solver
    solver_chi_Int = ode(odefuncIntegral)
    solver_chi_Int.set_integrator('dop853')

    # Set initial conditions
    solver_chi_Int.set_initial_value([chi_u_begin, dchi_du_begin], t=0)
    
    # Solve the ODE
    q = 1
    solution_Int.append([u[0], chi_u_begin, dchi_du_begin, a[0]])
    while solver_chi_Int.successful() and solver_chi_Int.t < u[-1] and q<len(u):
        solver_chi_Int.set_f_params(aprime_over_a[q], Integral[q], F_nu[q])
        solver_chi_Int.integrate(u[q])
        solution_Int.append([solver_chi_Int.t, *solver_chi_Int.y, a[q]]) #contains time, chi, deriv of chi, a
        if not solver_chi_Int.successful():
            print('error Int', q)
        q+=1

    # Extract the results
    solution_Int = np.array(solution_Int)

    #Match to WKB solution
    def WKB(x, b, c):
        return b*np.sin(x+c)
    a_u_latest = solution_Int[:,3][-1000:]
    #aprime_latest = solution_Int[:,4][1000:]
    xdata = solution_Int[:,0][-1000:] 
    ydata = solution_Int[:,1][-1000:]*a_u_latest 
    initial_guess = [10**(-10),0.1]
    popt, pcov = curve_fit(WKB, xdata, ydata, p0 = initial_guess)

    #Use a WKB approximation to find chi'
    tau_0 = tau[-1]
    A = popt[0]
    delta = popt[1]
    da_du0 = 1/kc_rad[loop]*aprime[-1]
    chi_prime_0 = A*np.cos(kc_rad[loop]*tau_0+delta)/a0 - 1/a0**2*da_du0*A*np.sin(kc_rad[loop]*tau_0+delta)
    solution_Chiprime_rad[loop,0], solution_Chiprime_rad[loop,1] = kc_rad[loop], chi_prime_0
    list_A_rad[loop, 0], list_A_rad[loop,1] = kc_rad[loop], A
 
A_rad_SM_panda = pd.DataFrame(list(zip(np.transpose(list_A_rad[:,0]), np.transpose(list_A_rad[:,1]))), columns=['kc', "A"])
A_rad_SM_panda.to_csv('A_rad_SUSY_precise.csv', index=False)
#Write the rest
ChiPrime_Rad_SM_panda = pd.DataFrame(list(zip(np.transpose(solution_Chiprime_rad[:,0]), np.transpose(solution_Chiprime_rad[:,1]))), columns=['kc', "chi_prime"])
ChiPrime_Rad_SM_panda.to_csv('ChiPrime_Rad_SUSY_precise.csv', index=False)
# Out:
# 9.865610189155583e-15
# C:\Users\Annet\AppData\Local\Temp\ipykernel_17304\2877140166.py:36: RuntimeWarning: divide by zero encountered in divide
#   aprime_over_a = 1/kc_rad[loop]*(aprime/a)
# First Solution done
# Integral Done
# 9.972263177733934e-15
# First Solution done
# Integral Done
# 1.0080069147197846e-14
# First Solution done
# Integral Done
# 1.0189040561941845e-14
# First Solution done
# Integral Done
# 1.0299190021107733e-14
# First Solution done
# Integral Done
# 1.0410530260041446e-14
# First Solution done
# Integral Done
# 1.0523074151765352e-14
# First Solution done
# Integral Done
# 1.0636834708466733e-14
# First Solution done
# Integral Done
# 1.07518250830022e-14
# First Solution done
# Integral Done
# 1.086805857041833e-14
# First Solution done
# Integral Done
# 1.0985548609488956e-14
# First Solution done
# Integral Done
# 1.1104308784268885e-14
# First Solution done
# Integral Done
# 1.1224352825664388e-14
# First Solution done
# Integral Done
# 1.1345694613020923e-14
# First Solution done
# Integral Done
# 1.1468348175727655e-14
# First Solution done
# Integral Done
# 1.1592327694839703e-14
# First Solution done
# Integral Done
# 1.1717647504717564e-14
# First Solution done
# Integral Done
# 1.1844322094684562e-14
# First Solution done
# Integral Done
# 1.1972366110702069e-14
# First Solution done
# Integral Done
# 1.210179435706273e-14
# First Solution done
# Integral Done
# 1.2232621798102305e-14
# First Solution done
# Integral Done
# 1.2364863559929705e-14
# First Solution done
# Integral Done
# 1.2498534932175834e-14
# First Solution done
# Integral Done
# 1.2633651369761494e-14
# First Solution done
# Integral Done
# 1.2770228494684073e-14
# First Solution done
# Integral Done
# 1.290828209782396e-14
# First Solution done
# Integral Done
# 1.3047828140770023e-14
# First Solution done
# Integral Done
# 1.3188882757665315e-14
# First Solution done
# Integral Done
# 1.3331462257072321e-14
# First Solution done
# Integral Done
# 1.3475583123858536e-14
# First Solution done
# Integral Done
# 1.3621262021102527e-14
# First Solution done
# Integral Done
# 1.3768515792020446e-14
# First Solution done
# Integral Done
# 1.391736146191333e-14
# First Solution done
# Integral Done
# 1.406781624013575e-14
# First Solution done
# Integral Done
# 1.4219897522085295e-14
# First Solution done
# Integral Done
# 1.4373622891214043e-14
# First Solution done
# Integral Done
# 1.4529010121061315e-14
# First Solution done
# Integral Done
# 1.4686077177308812e-14
# First Solution done
# Integral Done
# 1.4844842219857733e-14
# First Solution done
# Integral Done
# 1.500532360492826e-14
# First Solution done
# Integral Done
# 1.516753988718212e-14
# First Solution done
# Integral Done
# 1.533150982186771e-14
# First Solution done
# Integral Done
# 1.5497252366988496e-14
# First Solution done
# Integral Done
# 1.566478668549513e-14
# First Solution done
# Integral Done
# 1.583413214750077e-14
# First Solution done
# Integral Done
# 1.6005308332520912e-14
# First Solution done
# Integral Done
# 1.6178335031736884e-14
# First Solution done
# Integral Done
# 1.6353232250284288e-14
# First Solution done
# Integral Done
# 1.6530020209565907e-14
# First Solution done
# Integral Done
# 1.6708719349589528e-14
# First Solution done
# Integral Done
# 1.6889350331331458e-14
# First Solution done
# Integral Done
# 1.7071934039125152e-14
# First Solution done
# Integral Done
# 1.725649158307578e-14
# First Solution done
# Integral Done
# 1.7443044301501165e-14
# First Solution done
# Integral Done
# 1.7631613763398646e-14
# First Solution done
# Integral Done
# 1.782222177093909e-14
# First Solution done
# Integral Done
# 1.8014890361987406e-14
# First Solution done
# Integral Done
# 1.820964181265073e-14
# First Solution done
# Integral Done
# 1.8406498639853903e-14
# First Solution done
# Integral Done
# 1.8605483603942722e-14
# First Solution done
# Integral Done
# 1.8806619711315674e-14
# First Solution done
# Integral Done
# 1.9009930217083792e-14
# First Solution done
# Integral Done
# 1.9215438627759308e-14
# First Solution done
# Integral Done
# 1.9423168703973667e-14
# First Solution done
# Integral Done
# 1.963314446322442e-14
# First Solution done
# Integral Done
# 1.9845390182652408e-14
# First Solution done
# Integral Done
# 2.0059930401848328e-14
# First Solution done
# Integral Done
# 2.027678992569027e-14
# First Solution done
# Integral Done
# 2.0495993827211476e-14
# First Solution done
# Integral Done
# 2.0717567450499163e-14
# First Solution done
# Integral Done
# 2.0941536413625008e-14
# First Solution done
# Integral Done
# 2.1167926611606937e-14
# First Solution done
# Integral Done
# 2.139676421940298e-14
# First Solution done
# Integral Done
# 2.1628075694937877e-14
# First Solution done
# Integral Done
# 2.1861887782161743e-14
# First Solution done
# Integral Done
# 2.209822751414255e-14
# First Solution done
# Integral Done
# 2.233712221619128e-14
# First Solution done
# Integral Done
# 2.2578599509021565e-14
# First Solution done
# Integral Done
# 2.282268731194306e-14
# First Solution done
# Integral Done
# 2.3069413846089228e-14
# First Solution done
# Integral Done
# 2.3318807637680577e-14
# First Solution done
# Integral Done
# 2.3570897521322655e-14
# First Solution done
# Integral Done
# 2.3825712643339737e-14
# First Solution done
# Integral Done
# 2.408328246514503e-14
# First Solution done
# Integral Done
# 2.4343636766646546e-14
# First Solution done
# Integral Done
# 2.4606805649690657e-14
# First Solution done
# Integral Done
# 2.4872819541542014e-14
# First Solution done
# Integral Done
# 2.5141709198401855e-14
# First Solution done
# Integral Done
# 2.5413505708963857e-14
# First Solution done
# Integral Done
# 2.5688240498008414e-14
# First Solution done
# Integral Done
# 2.5965945330036242e-14
# First Solution done
# Integral Done
# 2.6246652312940814e-14
# First Solution done
# Integral Done
# 2.6530393901720443e-14
# First Solution done
# Integral Done
# 2.6817202902231093e-14
# First Solution done
# Integral Done
# 2.7107112474978894e-14
# First Solution done
# Integral Done
# 2.740015613895458e-14
# First Solution done
# Integral Done
# 2.7696367775508468e-14
# First Solution done
# Integral Done
# 2.7995781632268134e-14
# First Solution done
# Integral Done
# 2.8298432327097976e-14
# First Solution done
# Integral Done
# 2.8604354852101465e-14
# First Solution done
# Integral Done
# 2.891358457766727e-14
# First Solution done
# Integral Done
# 2.9226157256558515e-14
# First Solution done
# Integral Done
# 2.954210902804637e-14
# First Solution done
# Integral Done
# 2.986147642208876e-14
# First Solution done
# Integral Done
# 3.0184296363553497e-14
# First Solution done
# Integral Done
# 3.051060617648795e-14
# First Solution done
# Integral Done
# 3.0840443588433936e-14
# First Solution done
# Integral Done
# 3.1173846734790104e-14
# First Solution done
# Integral Done
# 3.151085416322099e-14
# First Solution done
# Integral Done
# 3.185150483811362e-14
# First Solution done
# Integral Done
# 3.219583814508292e-14
# First Solution done
# Integral Done
# 3.2543893895525255e-14
# First Solution done
# Integral Done
# 3.289571233122119e-14
# First Solution done
# Integral Done
# 3.325133412898837e-14
# First Solution done
# Integral Done
# 3.361080040538468e-14
# First Solution done
# Integral Done
# 3.3974152721461913e-14
# First Solution done
# Integral Done
# 3.434143308757078e-14
# First Solution done
# Integral Done
# 3.4712683968218625e-14
# First Solution done
# Integral Done
# 3.5087948286978726e-14
# First Solution done
# Integral Done
# 3.546726943145308e-14
# First Solution done
# Integral Done
# 3.585069125828903e-14
# First Solution done
# Integral Done
# 3.623825809824986e-14
# First Solution done
# Integral Done
# 3.6630014761340024e-14
# First Solution done
# Integral Done
# 3.7026006541986254e-14
# First Solution done
# Integral Done
# 3.742627922427451e-14
# First Solution done
# Integral Done
# 3.7830879087243404e-14
# First Solution done
# Integral Done
# 3.823985291023461e-14
# First Solution done
# Integral Done
# 3.865324797830201e-14
# First Solution done
# Integral Done
# 3.9071112087678387e-14
# First Solution done
# Integral Done
# 3.9493493551301426e-14
# First Solution done
# Integral Done
# 3.992044120439999e-14
# First Solution done
# Integral Done
# 4.035200441014025e-14
# First Solution done
# Integral Done
# 4.07882330653327e-14
# First Solution done
# Integral Done
# 4.1229177606201445e-14
# First Solution done
# Integral Done
# 4.1674889014215694e-14
# First Solution done
# Integral Done
# 4.2125418821983986e-14
# First Solution done
# Integral Done
# 4.258081911921215e-14
# First Solution done
# Integral Done
# 4.3041142558726225e-14
# First Solution done
# Integral Done
# 4.350644236256004e-14
# First Solution done
# Integral Done
# 4.39767723281083e-14
# First Solution done
# Integral Done
# 4.445218683434707e-14
# First Solution done
# Integral Done
# 4.493274084812087e-14
# First Solution done
# Integral Done
# 4.541848993049757e-14
# First Solution done
# Integral Done
# 4.5909490243192596e-14
# First Solution done
# Integral Done
# 4.640579855506227e-14
# First Solution done
# Integral Done
# 4.6907472248667435e-14
# First Solution done
# Integral Done
# 4.7414569326907425e-14
# First Solution done
# Integral Done
# 4.792714841972704e-14
# First Solution done
# Integral Done
# 4.8445268790894826e-14
# First Solution done
# Integral Done
# 4.896899034485497e-14
# First Solution done
# Integral Done
# 4.9498373633653784e-14
# First Solution done
# Integral Done
# 5.003347986394048e-14
# First Solution done
# Integral Done
# 5.057437090404356e-14
# First Solution done
# Integral Done
# 5.112110929112421e-14
# First Solution done
# Integral Done
# 5.1673758238406855e-14
# First Solution done
# Integral Done
# 5.223238164248777e-14
# First Solution done
# Integral Done
# 5.2797044090722224e-14
# First Solution done
# Integral Done
# 5.336781086869275e-14
# First Solution done
# Integral Done
# 5.3944747967757026e-14
# First Solution done
# Integral Done
# 5.452792209267737e-14
# First Solution done
# Integral Done
# 5.511740066933379e-14
# First Solution done
# Integral Done
# 5.571325185251925e-14
# First Solution done
# Integral Done
# 5.63155445338195e-14
# First Solution done
# Integral Done
# 5.692434834957842e-14
# First Solution done
# Integral Done
# 5.753973368894953e-14
# First Solution done
# Integral Done
# 5.816177170203408e-14
# First Solution done
# Integral Done
# 5.879053430810696e-14
# First Solution done
# Integral Done
# 5.942609420393264e-14
# First Solution done
# Integral Done
# 6.006852487216995e-14
# First Solution done
# Integral Done
# 6.071790058986779e-14
# First Solution done
# Integral Done
# 6.137429643705303e-14
# First Solution done
# Integral Done
# 6.203778830541213e-14
# First Solution done
# Integral Done
# 6.270845290706407e-14
# First Solution done
# Integral Done
# 6.338636778343061e-14
# First Solution done
# Integral Done
# 6.407161131420171e-14
# First Solution done
# Integral Done
# 6.476426272639732e-14
# First Solution done
# Integral Done
# 6.54644021035273e-14
# First Solution done
# Integral Done
# 6.61721103948512e-14
# First Solution done
# Integral Done
# 6.688746942473715e-14
# First Solution done
# Integral Done
# 6.761056190212218e-14
# First Solution done
# Integral Done
# 6.834147143007481e-14
# First Solution done
# Integral Done
# 6.908028251546223e-14
# First Solution done
# Integral Done
# 6.982708057871934e-14
# First Solution done
# Integral Done
# 7.058195196372565e-14
# First Solution done
# Integral Done
# 7.134498394778865e-14
# First Solution done
# Integral Done
# 7.211626475173432e-14
# First Solution done
# Integral Done
# 7.289588355010657e-14
# First Solution done
# Integral Done
# 7.368393048147861e-14
# First Solution done
# Integral Done
# 7.448049665887407e-14
# First Solution done
# Integral Done
# 7.528567418030104e-14
# First Solution done
# Integral Done
# 7.609955613940056e-14
# First Solution done
# Integral Done
# 7.692223663621105e-14
# First Solution done
# Integral Done
# 7.775381078804617e-14
# First Solution done
# Integral Done
# 7.859437474049331e-14
# First Solution done
# Integral Done
# 7.944402567852986e-14
# First Solution done
# Integral Done
# 8.030286183775943e-14
# First Solution done
# Integral Done
# 8.117098251576918e-14
# First Solution done
# Integral Done
# 8.204848808361157e-14
# First Solution done
# Integral Done
# 8.293547999740838e-14
# First Solution done
# Integral Done
# 8.383206081008091e-14
# First Solution done
# Integral Done
# 8.47383341832071e-14
# First Solution done
# Integral Done
# 8.565440489900778e-14
# First Solution done
# Integral Done
# 8.65803788724596e-14
# First Solution done
# Integral Done
# 8.751636316354199e-14
# First Solution done
# Integral Done
# 8.846246598961538e-14
# First Solution done
# Integral Done
# 8.94187967379328e-14
# First Solution done
# Integral Done
# 9.038546597828674e-14
# First Solution done
# Integral Done
# 9.136258547579392e-14
# First Solution done
# Integral Done
# 9.235026820381709e-14
# First Solution done
# Integral Done
# 9.334862835702649e-14
# First Solution done
# Integral Done
# 9.43577813646029e-14
# First Solution done
# Integral Done
# 9.537784390358498e-14
# First Solution done
# Integral Done
# 9.640893391235694e-14
# First Solution done
# Integral Done
# 9.745117060428565e-14
# First Solution done
# Integral Done
# 9.850467448150435e-14
# First Solution done
# Integral Done
# 9.956956734884451e-14
# First Solution done
# Integral Done
# 1.0064597232791807e-13
# First Solution done
# Integral Done
# 1.0173401387135383e-13
# First Solution done
# Integral Done
# 1.0283381777718604e-13
# First Solution done
# Integral Done
# 1.0394551120339848e-13
# First Solution done
# Integral Done
# 1.0506922268262649e-13
# First Solution done
# Integral Done
# 1.0620508213701929e-13
# First Solution done
# Integral Done
# 1.0735322089325893e-13
# First Solution done
# Integral Done
# 1.0851377169774556e-13
# First Solution done
# Integral Done
# 1.096868687319455e-13
# First Solution done
# Integral Done
# 1.1087264762790498e-13
# First Solution done
# Integral Done
# 1.1207124548393082e-13
# First Solution done
# Integral Done
# 1.1328280088044298e-13
# First Solution done
# Integral Done
# 1.1450745389599658e-13
# First Solution done
# Integral Done
# 1.1574534612347685e-13
# First Solution done
# Integral Done
# 1.1699662068647035e-13
# First Solution done
# Integral Done
# 1.1826142225581434e-13
# First Solution done
# Integral Done
# 1.1953989706632056e-13
# First Solution done
# Integral Done
# 1.208321929336845e-13
# First Solution done
# Integral Done
# 1.2213845927157576e-13
# First Solution done
# Integral Done
# 1.2345884710891276e-13
# First Solution done
# Integral Done
# 1.247935091073236e-13
# First Solution done
# Integral Done
# 1.2614259957879828e-13
# First Solution done
# Integral Done
# 1.275062745035292e-13
# First Solution done
# Integral Done
# 1.2888469154794488e-13
# First Solution done
# Integral Done
# 1.3027801008293974e-13
# First Solution done
# Integral Done
# 1.3168639120230086e-13
# First Solution done
# Integral Done
# 1.3310999774133298e-13
# First Solution done
# Integral Done
# 1.3454899429568426e-13
# First Solution done
# Integral Done
# 1.360035472403787e-13
# First Solution done
# Integral Done
# 1.37473824749051e-13
# First Solution done
# Integral Done
# 1.3895999681338983e-13
# First Solution done
# Integral Done
# 1.4046223526279408e-13
# First Solution done
# Integral Done
# 1.4198071378423814e-13
# First Solution done
# Integral Done
# 1.4351560794235331e-13
# First Solution done
# Integral Done
# 1.4506709519972674e-13
# First Solution done
# Integral Done
# 1.4663535493741993e-13
# First Solution done
# Integral Done
# 1.4822056847570811e-13
# First Solution done
# Integral Done
# 1.4982291909504332e-13
# First Solution done
# Integral Done
# 1.5144259205724696e-13
# First Solution done
# Integral Done
# 1.5307977462692848e-13
# First Solution done
# Integral Done
# 1.5473465609313573e-13
# First Solution done
# Integral Done
# 1.564074277912425e-13
# First Solution done
# Integral Done
# 1.580982831250692e-13
# First Solution done
# Integral Done
# 1.5980741758924356e-13
# First Solution done
# Integral Done
# 1.6153502879180385e-13
# First Solution done
# Integral Done
# 1.632813164770471e-13
# First Solution done
# Integral Done
# 1.6504648254862237e-13
# First Solution done
# Integral Done
# 1.6683073109287373e-13
# First Solution done
# Integral Done
# 1.6863426840243834e-13
# First Solution done
# Integral Done
# 1.7045730300009696e-13
# First Solution done
# Integral Done
# 1.7230004566288188e-13
# First Solution done
# Integral Done
# 1.7416270944644882e-13
# First Solution done
# Integral Done
# 1.7604550970970924e-13
# First Solution done
# Integral Done
# 1.7794866413972908e-13
# First Solution done
# Integral Done
# 1.7987239277689798e-13
# First Solution done
# Integral Done
# 1.8181691804037114e-13
# First Solution done
# Integral Done
# 1.8378246475378435e-13
# First Solution done
# Integral Done
# 1.8576926017124661e-13
# First Solution done
# Integral Done
# 1.8777753400361713e-13
# First Solution done
# Integral Done
# 1.898075184450633e-13
# First Solution done
# Integral Done
# 1.9185944819990553e-13
# First Solution done
# Integral Done
# 1.9393356050975558e-13
# First Solution done
# Integral Done
# 1.9603009518094517e-13
# First Solution done
# Integral Done
# 1.9814929461225134e-13
# First Solution done
# Integral Done
# 2.0029140382292284e-13
# First Solution done
# Integral Done
# 2.0245667048101005e-13
# First Solution done
# Integral Done
# 2.0464534493199915e-13
# First Solution done
# Integral Done
# 2.068576802277554e-13
# First Solution done
# Integral Done
# 2.0909393215578326e-13
# First Solution done
# Integral Done
# 2.113543592687992e-13
# First Solution done
# Integral Done
# 2.1363922291462352e-13
# First Solution done
# Integral Done
# 2.1594878726640007e-13
# First Solution done
# Integral Done
# 2.1828331935313803e-13
# First Solution done
# Integral Done
# 2.206430890905847e-13
# First Solution done
# Integral Done
# 2.230283693124338e-13
# First Solution done
# Integral Done
# 2.2543943580187098e-13
# First Solution done
# Integral Done
# 2.278765673234586e-13
# First Solution done
# Integral Done
# 2.303400456553648e-13
# First Solution done
# Integral Done
# 2.328301556219453e-13
# First Solution done
# Integral Done
# 2.353471851266726e-13
# First Solution done
# Integral Done
# 2.3789142518542217e-13
# First Solution done
# Integral Done
# 2.404631699601218e-13
# First Solution done
# Integral Done
# 2.4306271679276085e-13
# First Solution done
# Integral Done
# 2.456903662397679e-13
# First Solution done
# Integral Done
# 2.483464221067613e-13
# First Solution done
# Integral Done
# 2.5103119148367585e-13
# First Solution done
# Integral Done
# 2.537449847802677e-13
# First Solution done
# Integral Done
# 2.5648811576200126e-13
# First Solution done
# Integral Done
# 2.592609015863299e-13
# First Solution done
# Integral Done
# 2.6206366283936356e-13
# First Solution done
# Integral Done
# 2.648967235729334e-13
# First Solution done
# Integral Done
# 2.677604113420606e-13
# First Solution done
# Integral Done
# 2.7065505724282707e-13
# First Solution done
# Integral Done
# 2.7358099595065505e-13
# First Solution done
# Integral Done
# 2.765385657590028e-13
# First Solution done
# Integral Done
# 2.7952810861847865e-13
# First Solution done
# Integral Done
# 2.8254997017637656e-13
# First Solution done
# Integral Done
# 2.856044998166368e-13
# First Solution done
# Integral Done
# 2.8869205070024527e-13
# First Solution done
# Integral Done
# 2.9181297980606365e-13
# First Solution done
# Integral Done
# 2.9496764797210186e-13
# First Solution done
# Integral Done
# 2.9815641993723785e-13
# First Solution done
# Integral Done
# 3.0137966438339315e-13
# First Solution done
# Integral Done
# 3.0463775397815145e-13
# First Solution done
# Integral Done
# 3.0793106541785077e-13
# First Solution done
# Integral Done
# 3.1125997947113695e-13
# First Solution done
# Integral Done
# 3.146248810229867e-13
# First Solution done
# Integral Done
# 3.1802615911920496e-13
# First Solution done
# Integral Done
# 3.214642070114109e-13
# First Solution done
# Integral Done
# 3.2493942220250203e-13
# First Solution done
# Integral Done
# 3.2845220649261246e-13
# First Solution done
# Integral Done
# 3.320029660255691e-13
# First Solution done
# Integral Done
# 3.355921113358537e-13
# First Solution done
# Integral Done
# 3.39220057396061e-13
# First Solution done
# Integral Done
# 3.4288722366488145e-13
# First Solution done
# Integral Done
# 3.4659403413559967e-13
# First Solution done
# Integral Done
# 3.5034091738511445e-13
# First Solution done
# Integral Done
# 3.5412830662324224e-13
# First Solution done
# Integral Done
# 3.579566397437506e-13
# First Solution done
# Integral Done
# 3.6182635937393573e-13
# First Solution done
# Integral Done
# 3.6573791292526e-13
# First Solution done
# Integral Done
# 3.696917526475675e-13
# First Solution done
# Integral Done
# 3.7368833567871025e-13
# First Solution done
# Integral Done
# 3.7772812409839795e-13
# First Solution done
# Integral Done
# 3.8181158498239995e-13
# First Solution done
# Integral Done
# 3.859391904556904e-13
# First Solution done
# Integral Done
# 3.901114177462988e-13
# First Solution done
# Integral Done
# 3.943287492426788e-13
# First Solution done
# Integral Done
# 3.9859167254720615e-13
# First Solution done
# Integral Done
# 4.0290068053425206e-13
# First Solution done
# Integral Done
# 4.0725627140544035e-13
# First Solution done
# Integral Done
# 4.1165894874912927e-13
# First Solution done
# Integral Done
# 4.1610922159778003e-13
# First Solution done
# Integral Done
# 4.2060760448603057e-13
# First Solution done
# Integral Done
# 4.251546175119365e-13
# First Solution done
# Integral Done
# 4.297507863950439e-13
# First Solution done
# Integral Done
# 4.343966425393904e-13
# First Solution done
# Integral Done
# 4.39092723092634e-13
# First Solution done
# Integral Done
# 4.438395710101101e-13
# First Solution done
# Integral Done
# 4.486377351164236e-13
# First Solution done
# Integral Done
# 4.534877701695063e-13
# First Solution done
# Integral Done
# 4.583902369250247e-13
# First Solution done
# Integral Done
# 4.633457021993812e-13
# First Solution done
# Integral Done
# 4.683547389376419e-13
# First Solution done
# Integral Done
# 4.734179262790009e-13
# First Solution done
# Integral Done
# 4.785358496222453e-13
# First Solution done
# Integral Done
# 4.83709100696146e-13
# First Solution done
# Integral Done
# 4.889382776249235e-13
# First Solution done
# Integral Done
# 4.94223985000398e-13
# First Solution done
# Integral Done
# 4.995668339492144e-13
# First Solution done
# Integral Done
# 5.049674422049941e-13
# First Solution done
# Integral Done
# 5.104264341794301e-13
# First Solution done
# Integral Done
# 5.159444410344393e-13
# First Solution done
# Integral Done
# 5.215221007557214e-13
# First Solution done
# Integral Done
# 5.271600582249106e-13
# First Solution done
# Integral Done
# 5.32858965296303e-13
# First Solution done
# Integral Done
# 5.38619480870064e-13
# First Solution done
# Integral Done
# 5.444422709700109e-13
# First Solution done
# Integral Done
# 5.503280088206924e-13
# First Solution done
# Integral Done
# 5.562773749230594e-13
# First Solution done
# Integral Done
# 5.622910571357681e-13
# First Solution done
# Integral Done
# 5.683697507540181e-13
# First Solution done
# Integral Done
# 5.7451415858804e-13
# First Solution done
# Integral Done
# 5.807249910475651e-13
# First Solution done
# Integral Done
# 5.870029662206645e-13
# First Solution done
# Integral Done
# 5.933488099599789e-13
# First Solution done
# Integral Done
# 5.997632559636691e-13
# First Solution done
# Integral Done
# 6.062470458623505e-13
# First Solution done
# Integral Done
# 6.128009293035624e-13
# First Solution done
# Integral Done
# 6.194256640397588e-13
# First Solution done
# Integral Done
# 6.261220160145371e-13
# First Solution done
# Integral Done
# 6.32890759451685e-13
# First Solution done
# Integral Done
# 6.39732676945633e-13
# First Solution done
# Integral Done
# 6.466485595497972e-13
# First Solution done
# Integral Done
# 6.536392068705511e-13
# First Solution done
# Integral Done
# 6.607054271576803e-13
# First Solution done
# Integral Done
# 6.678480373994106e-13
# First Solution done
# Integral Done
# 6.750678634149736e-13
# First Solution done
# Integral Done
# 6.823657399524511e-13
# First Solution done
# Integral Done
# 6.897425107831008e-13
# First Solution done
# Integral Done
# 6.971990287999037e-13
# First Solution done
# Integral Done
# 7.0473615611717e-13
# First Solution done
# Integral Done
# 7.123547641673263e-13
# First Solution done
# Integral Done
# 7.200557338054484e-13
# First Solution done
# Integral Done
# 7.278399554074581e-13
# First Solution done
# Integral Done
# 7.357083289760622e-13
# First Solution done
# Integral Done
# 7.436617642431723e-13
# First Solution done
# Integral Done
# 7.517011807744383e-13
# First Solution done
# Integral Done
# 7.598275080783538e-13
# First Solution done
# Integral Done
# 7.680416857100854e-13
# First Solution done
# Integral Done
# 7.763446633833944e-13
# First Solution done
# Integral Done
# 7.847374010779864e-13
# First Solution done
# Integral Done
# 7.932208691524872e-13
# First Solution done
# Integral Done
# 8.017960484546094e-13
# First Solution done
# Integral Done
# 8.104639304365921e-13
# First Solution done
# Integral Done
# 8.19225517267829e-13
# First Solution done
# Integral Done
# 8.280818219527754e-13
# First Solution done
# Integral Done
# 8.370338684460371e-13
# First Solution done
# Integral Done
# 8.460826917727423e-13
# First Solution done
# Integral Done
# 8.552293381464465e-13
# First Solution done
# Integral Done
# 8.644748650916148e-13
# First Solution done
# Integral Done
# 8.73820341564344e-13
# First Solution done
# Integral Done
# 8.832668480773077e-13
# First Solution done
# Integral Done
# 8.928154768247019e-13
# First Solution done
# Integral Done
# 9.024673318064872e-13
# First Solution done
# Integral Done
# 9.122235289586127e-13
# First Solution done
# Integral Done
# 9.220851962804257e-13
# First Solution done
# Integral Done
# 9.320534739666562e-13
# First Solution done
# Integral Done
# 9.42129514536586e-13
# First Solution done
# Integral Done
# 9.523144829699046e-13
# First Solution done
# Integral Done
# 9.626095568404545e-13
# First Solution done
# Integral Done
# 9.730159264520866e-13
# First Solution done
# Integral Done
# 9.835347949762766e-13
# First Solution done
# Integral Done
# 9.941673785918528e-13
# First Solution done
# Integral Done
# 1.004914906625074e-12
# First Solution done
# Integral Done
# 1.0157786216921768e-12
# First Solution done
# Integral Done
# 1.0267597798426195e-12
# First Solution done
# Integral Done
# 1.037859650704443e-12
# First Solution done
# Integral Done
# 1.0490795176310364e-12
# First Solution done
# Integral Done
# 1.0604206778500177e-12
# First Solution done
# Integral Done
# 1.0718844426121103e-12
# First Solution done
# Integral Done
# 1.0834721373438937e-12
# First Solution done
# Integral Done
# 1.0951851018005564e-12
# First Solution done
# Integral Done
# 1.1070246902207533e-12
# First Solution done
# Integral Done
# 1.1189922714832313e-12
# First Solution done
# Integral Done
# 1.131089229264858e-12
# First Solution done
# Integral Done
# 1.1433169622014652e-12
# First Solution done
# Integral Done
# 1.1556768840483455e-12
# First Solution done
# Integral Done
# 1.1681704238449658e-12
# First Solution done
# Integral Done
# 1.1807990260786298e-12
# First Solution done
# Integral Done
# 1.1935641508534198e-12
# First Solution done
# Integral Done
# 1.2064672740566706e-12
# First Solution done
# Integral Done
# 1.2195098875324873e-12
# First Solution done
# Integral Done
# 1.2326934992517403e-12
# First Solution done
# Integral Done
# 1.2460196334873426e-12
# First Solution done
# Integral Done
# 1.2594898309905787e-12
# First Solution done
# Integral Done
# 1.2731056491695516e-12
# First Solution done
# Integral Done
# 1.2868686622679732e-12
# First Solution done
# Integral Done
# 1.3007804615492442e-12
# First Solution done
# Integral Done
# 1.3148426554784117e-12
# First Solution done
# Integral Done
# 1.3290568699090646e-12
# First Solution done
# Integral Done
# 1.3434247482712752e-12
# First Solution done
# Integral Done
# 1.3579479517616602e-12
# First Solution done
# Integral Done
# 1.3726281595351968e-12
# First Solution done
# Integral Done
# 1.3874670688995055e-12
# First Solution done
# Integral Done
# 1.402466395511242e-12
# First Solution done
# Integral Done
# 1.4176278735742503e-12
# First Solution done
# Integral Done
# 1.43295325604018e-12
# First Solution done
# Integral Done
# 1.4484443148112144e-12
# First Solution done
# Integral Done
# 1.4641028409438558e-12
# First Solution done
# Integral Done
# 1.4799306448586901e-12
# First Solution done
# Integral Done
# 1.495929556546639e-12
# First Solution done
# Integral Done
# 1.512101425782244e-12
# First Solution done
# Integral Done
# 1.5284481223373074e-12
# First Solution done
# Integral Done
# 1.5449715361969937e-12
# First Solution done
# Integral Done
# 1.561673577778398e-12
# First Solution done
# Integral Done
# 1.5785561781505186e-12
# First Solution done
# Integral Done
# 1.5956212892598639e-12
# First Solution done
# Integral Done
# 1.6128708841532423e-12
# First Solution done
# Integral Done
# 1.6303069572079436e-12
# First Solution done
# Integral Done
# 1.6479315243612153e-12
# First Solution done
# Integral Done
# 1.6657466233439657e-12
# First Solution done
# Integral Done
# 1.6837543139162215e-12
# First Solution done
# Integral Done
# 1.7019566781054065e-12
# First Solution done
# Integral Done
# 1.720355820446378e-12
# First Solution done
# Integral Done
# 1.7389538682256826e-12
# First Solution done
# Integral Done
# 1.7577529717265252e-12
# First Solution done
# Integral Done
# 1.7767553044786548e-12
# First Solution done
# Integral Done
# 1.7959630635082604e-12
# First Solution done
# Integral Done
# 1.8153784695934894e-12
# First Solution done
# Integral Done
# 1.8350037675192672e-12
# First Solution done
# Integral Done
# 1.8548412263391546e-12
# First Solution done
# Integral Done
# 1.8748931396354476e-12
# First Solution done
# Integral Done
# 1.8951618257859593e-12
# First Solution done
# Integral Done
# 1.9156496282311585e-12
# First Solution done
# Integral Done
# 1.9363589157465864e-12
# First Solution done
# Integral Done
# 1.957292082713864e-12
# First Solution done
# Integral Done
# 1.9784515494004992e-12
# First Solution done
# Integral Done
# 1.9998397622386416e-12
# First Solution done
# Integral Done
# 2.0214591941066456e-12
# First Solution done
# Integral Done
# 2.0433123446169762e-12
# First Solution done
# Integral Done
# 2.06540174040446e-12
# First Solution done
# Integral Done
# 2.0877299354177117e-12
# First Solution done
# Integral Done
# 2.11029951121548e-12
# First Solution done
# Integral Done
# 2.1331130772647597e-12
# First Solution done
# Integral Done
# 2.156173271242066e-12
# First Solution done
# Integral Done
# 2.1794827593385855e-12
# First Solution done
# Integral Done
# 2.2030442365695465e-12
# First Solution done
# Integral Done
# 2.2268604270832393e-12
# First Solution done
# Integral Done
# 2.2509340844791892e-12
# First Solution done
# Integral Done
# 2.275267992123861e-12
# First Solution done
# Integral Done
# 2.299864963474463e-12
# First Solution done
# Integral Done
# 2.324727842402045e-12
# First Solution done
# Integral Done
# 2.3498595035230446e-12
# First Solution done
# Integral Done
# 2.3752628525287196e-12
# First Solution done
# Integral Done
# 2.400940826523732e-12
# First Solution done
# Integral Done
# 2.4268963943636814e-12
# First Solution done
# Integral Done
# 2.4531325570000175e-12
# First Solution done
# Integral Done
# 2.4796523478256713e-12
# First Solution done
# Integral Done
# 2.5064588330263047e-12
# First Solution done
# Integral Done
# 2.5335551119350893e-12
# First Solution done
# Integral Done
# 2.5609443173906455e-12
# First Solution done
# Integral Done
# 2.588629616099562e-12
# First Solution done
# Integral Done
# 2.616614209002083e-12
# First Solution done
# Integral Done
# 2.644901331642718e-12
# First Solution done
# Integral Done
# 2.673494254544375e-12
# First Solution done
# Integral Done
# 2.702396283585311e-12
# First Solution done
# Integral Done
# 2.7316107603831155e-12
# First Solution done
# Integral Done
# 2.7611410626797586e-12
# First Solution done
# Integral Done
# 2.790990604732965e-12
# First Solution done
# Integral Done
# 2.8211628377100595e-12
# First Solution done
# Integral Done
# 2.851661250088142e-12
# First Solution done
# Integral Done
# 2.8824893680556744e-12
# First Solution done
# Integral Done
# 2.9136507559228647e-12
# First Solution done
# Integral Done
# 2.9451490165306428e-12
# First Solution done
# Integral Done
# 2.9769877916694925e-12
# First Solution done
# Integral Done
# 3.009170762500042e-12
# First Solution done
# Integral Done
# 3.04170164997788e-12
# First Solution done
# Integral Done
# 3.0745842152843518e-12
# First Solution done
# Integral Done
# 3.1078222602615815e-12
# First Solution done
# Integral Done
# 3.141419627852069e-12
# First Solution done
# Integral Done
# 3.1753802025418063e-12
# First Solution done
# Integral Done
# 3.209707910811137e-12
# First Solution done
# Integral Done
# 3.244406721588082e-12
# First Solution done
# Integral Done
# 3.2794806467062327e-12
# First Solution done
# Integral Done
# 3.3149337413703987e-12
# First Solution done
# Integral Done
# 3.3507701046240066e-12
# First Solution done
# Integral Done
# 3.3869938798235407e-12
# First Solution done
# Integral Done
# 3.4236092551175602e-12
# First Solution done
# Integral Done
# 3.4606204639309967e-12
# First Solution done
# Integral Done
# 3.4980317854547253e-12
# First Solution done
# Integral Done
# 3.5358475451397177e-12
# First Solution done
# Integral Done
# 3.5740721151982288e-12
# First Solution done
# Integral Done
# 3.6127099151085155e-12
# First Solution done
# Integral Done
# 3.651765412125514e-12
# First Solution done
# Integral Done
# 3.691243121798237e-12
# First Solution done
# Integral Done
# 3.731147608490658e-12
# First Solution done
# Integral Done
# 3.7714834859117704e-12
# First Solution done
# Integral Done
# 3.812255417645636e-12
# First Solution done
# Integral Done
# 3.8534681176937514e-12
# First Solution done
# Integral Done
# 3.895126351017775e-12
# First Solution done
# Integral Done
# 3.937234934091742e-12
# First Solution done
# Integral Done
# 3.9797987354588754e-12
# First Solution done
# Integral Done
# 4.0228226762936494e-12
# First Solution done
# Integral Done
# 4.0663117309716265e-12
# First Solution done
# Integral Done
# 4.110270927643847e-12
# First Solution done
# Integral Done
# 4.15470534881967e-12
# First Solution done
# Integral Done
# 4.199620131952089e-12
# First Solution done
# Integral Done
# 4.245020470033245e-12
# First Solution done
# Integral Done
# 4.2909116121952135e-12
# First Solution done
# Integral Done
# 4.337298864315738e-12
# First Solution done
# Integral Done
# 4.384187589632034e-12
# First Solution done
# Integral Done
# 4.431583209361305e-12
# First Solution done
# Integral Done
# 4.479491203327221e-12
# First Solution done
# Integral Done
# 4.527917110593445e-12
# First Solution done
# Integral Done
# 4.576866530104207e-12
# First Solution done
# Integral Done
# 4.626345121331901e-12
# First Solution done
# Integral Done
# 4.6763586049303164e-12
# First Solution done
# Integral Done
# 4.7269127633977475e-12
# First Solution done
# Integral Done
# 4.778013441743936e-12
# First Solution done
# Integral Done
# 4.8296665481672505e-12
# First Solution done
# Integral Done
# 4.88187805473643e-12
# First Solution done
# Integral Done
# 4.934653998081829e-12
# First Solution done
# Integral Done
# 4.988000480094059e-12
# First Solution done
# Integral Done
# 5.041923668627909e-12
# First Solution done
# Integral Done
# 5.096429798216814e-12
# First Solution done
# Integral Done
# 5.151525170792617e-12
# First Solution done
# Integral Done
# 5.207216156415186e-12
# First Solution done
# Integral Done
# 5.263509194007996e-12
# First Solution done
# Integral Done
# 5.3204107921035865e-12
# First Solution done
# Integral Done
# 5.377927529594995e-12
# First Solution done
# Integral Done
# 5.436066056497388e-12
# First Solution done
# Integral Done
# 5.494833094715698e-12
# First Solution done
# Integral Done
# 5.554235438823844e-12
# First Solution done
# Integral Done
# 5.614279956847503e-12
# First Solution done
# Integral Done
# 5.6749735910609395e-12
# First Solution done
# Integral Done
# 5.7363233587880596e-12
# First Solution done
# Integral Done
# 5.7983363532136876e-12
# First Solution done
# Integral Done
# 5.861019744204674e-12
# First Solution done
# Integral Done
# 5.924380779138424e-12
# First Solution done
# Integral Done
# 5.988426783739832e-12
# First Solution done
# Integral Done
# 6.053165162930234e-12
# First Solution done
# Integral Done
# 6.118603401681241e-12
# First Solution done
# Integral Done
# 6.1847490658826745e-12
# First Solution done
# Integral Done
# 6.2516098032154366e-12
# First Solution done
# Integral Done
# 6.319193344035961e-12
# First Solution done
# Integral Done
# 6.387507502270913e-12
# First Solution done
# Integral Done
# 6.456560176319606e-12
# First Solution done
# Integral Done
# 6.5263593499680365e-12
# First Solution done
# Integral Done
# 6.5969130933113685e-12
# First Solution done
# Integral Done
# 6.668229563686987e-12
# First Solution done
# Integral Done
# 6.7403170066184365e-12
# First Solution done
# Integral Done
# 6.8131837567674865e-12
# First Solution done
# Integral Done
# 6.886838238898835e-12
# First Solution done
# Integral Done
# 6.961288968853996e-12
# First Solution done
# Integral Done
# 7.036544554535014e-12
# First Solution done
# Integral Done
# 7.1126136969008604e-12
# First Solution done
# Integral Done
# 7.189505190972987e-12
# First Solution done
# Integral Done
# 7.267227926852136e-12
# First Solution done
# Integral Done
# 7.345790890745696e-12
# First Solution done
# Integral Done
# 7.425203166007756e-12
# First Solution done
# Integral Done
# 7.505473934188644e-12
# First Solution done
# Integral Done
# 7.586612476096426e-12
# First Solution done
# Integral Done
# 7.668628172870044e-12
# First Solution done
# Integral Done
# 7.751530507064391e-12
# First Solution done
# Integral Done
# 7.835329063745973e-12
# First Solution done
# Integral Done
# 7.920033531601574e-12
# First Solution done
# Integral Done
# 8.005653704058189e-12
# First Solution done
# Integral Done
# 8.092199480415626e-12
# First Solution done
# Integral Done
# 8.179680866991086e-12
# First Solution done
# Integral Done
# 8.268107978274984e-12
# First Solution done
# Integral Done
# 8.35749103810264e-12
# First Solution done
# Integral Done
# 8.44784038083367e-12
# First Solution done
# Integral Done
# 8.539166452548667e-12
# First Solution done
# Integral Done
# 8.631479812256758e-12
# First Solution done
# Integral Done
# 8.72479113311586e-12
# First Solution done
# Integral Done
# 8.819111203666984e-12
# First Solution done
# Integral Done
# 8.914450929080895e-12
# First Solution done
# Integral Done
# 9.010821332420568e-12
# First Solution done
# Integral Done
# 9.108233555914239e-12
# First Solution done
# Integral Done
# 9.20669886224427e-12
# First Solution done
# Integral Done
# 9.306228635849053e-12
# First Solution done
# Integral Done
# 9.40683438423934e-12
# First Solution done
# Integral Done
# 9.508527739328975e-12
# First Solution done
# Integral Done
# 9.611320458779064e-12
# First Solution done
# Integral Done
# 9.715224427358625e-12
# First Solution done
# Integral Done
# 9.82025165831758e-12
# First Solution done
# Integral Done
# 9.926414294775945e-12
# First Solution done
# Integral Done
# 1.0033724611128144e-11
# First Solution done
# Integral Done
# 1.0142195014461767e-11
# First Solution done
# Integral Done
# 1.0251838045992127e-11
# First Solution done
# Integral Done
# 1.0362666382512712e-11
# First Solution done
# Integral Done
# 1.0474692837860737e-11
# First Solution done
# Integral Done
# 1.0587930364397822e-11
# First Solution done
# Integral Done
# 1.0702392054508288e-11
# First Solution done
# Integral Done
# 1.081809114211295e-11
# First Solution done
# Integral Done
# 1.093504100419941e-11
# First Solution done
# Integral Done
# 1.1053255162367525e-11
# First Solution done
# Integral Done
# 1.1172747284393509e-11
# First Solution done
# Integral Done
# 1.1293531185811277e-11
# First Solution done
# Integral Done
# 1.1415620831507193e-11
# First Solution done
# Integral Done
# 1.15390303373373e-11
# First Solution done
# Integral Done
# 1.1663773971758313e-11
# First Solution done
# Integral Done
# 1.178986615747583e-11
# First Solution done
# Integral Done
# 1.19173214731151e-11
# First Solution done
# Integral Done
# 1.2046154654904066e-11
# First Solution done
# Integral Done
# 1.217638059837723e-11
# First Solution done
# Integral Done
# 1.2308014360099521e-11
# First Solution done
# Integral Done
# 1.2441071159405702e-11
# First Solution done
# Integral Done
# 1.2575566380159782e-11
# First Solution done
# Integral Done
# 1.2711515572535607e-11
# First Solution done
# Integral Done
# 1.2848934454812191e-11
# First Solution done
# Integral Done
# 1.2987838915193342e-11
# First Solution done
# Integral Done
# 1.3128245013642427e-11
# First Solution done
# Integral Done
# 1.3270168983741426e-11
# First Solution done
# Integral Done
# 1.3413627234566161e-11
# First Solution done
# Integral Done
# 1.355863635258441e-11
# First Solution done
# Integral Done
# 1.3705213103573402e-11
# First Solution done
# Integral Done
# 1.3853374434558017e-11
# First Solution done
# Integral Done
# 1.4003137475769833e-11
# First Solution done
# Integral Done
# 1.4154519542629327e-11
# First Solution done
# Integral Done
# 1.4307538137746071e-11
# First Solution done
# Integral Done
# 1.4462210952942502e-11
# First Solution done
# Integral Done
# 1.4618555871301263e-11
# First Solution done
# Integral Done
# 1.4776590969230147e-11
# First Solution done
# Integral Done
# 1.4936334518554827e-11
# First Solution done
# Integral Done
# 1.5097804988628895e-11
# First Solution done
# Integral Done
# 1.5261021048470928e-11
# First Solution done
# Integral Done
# 1.5426001568921985e-11
# First Solution done
# Integral Done
# 1.559276562482884e-11
# First Solution done
# Integral Done
# 1.576133249724793e-11
# First Solution done
# Integral Done
# 1.593172167567432e-11
# First Solution done
# Integral Done
# 1.6103952860297756e-11
# First Solution done
# Integral Done
# 1.627804596427667e-11
# First Solution done
# Integral Done
# 1.6454021116043178e-11
# First Solution done
# Integral Done
# 1.663189866162915e-11
# First Solution done
# Integral Done
# 1.681169916701979e-11
# First Solution done
# Integral Done
# 1.6993443420528976e-11
# First Solution done
# Integral Done
# 1.7177152435205993e-11
# First Solution done
# Integral Done
# 1.7362847451262254e-11
# First Solution done
# Integral Done
# 1.7550549938528707e-11
# First Solution done
# Integral Done
# 1.7740281598937838e-11
# First Solution done
# Integral Done
# 1.7932064369032435e-11
# First Solution done
# Integral Done
# 1.8125920422501798e-11
# First Solution done
# Integral Done
# 1.8321872172745794e-11
# First Solution done
# Integral Done
# 1.851994227546734e-11
# First Solution done
# Integral Done
# 1.8720153631288545e-11
# First Solution done
# Integral Done
# 1.8922529388402722e-11
# First Solution done
# Integral Done
# 1.9127092945247172e-11
# First Solution done
# Integral Done
# 1.9333867953210402e-11
# First Solution done
# Integral Done
# 1.9542878319366568e-11
# First Solution done
# Integral Done
# 1.9754148209238664e-11
# First Solution done
# Integral Done
# 1.996770204959342e-11
# First Solution done
# Integral Done
# 2.0183564531264407e-11
# First Solution done
# Integral Done
# 2.0401760612008498e-11
# First Solution done
# Integral Done
# 2.0622315519389845e-11
# First Solution done
# Integral Done
# 2.0845254753697598e-11
# First Solution done
# Integral Done
# 2.1070604090893586e-11
# First Solution done
# Integral Done
# 2.1298389585592337e-11
# First Solution done
# Integral Done
# 2.1528637574075275e-11
# First Solution done
# Integral Done
# 2.176137467733337e-11
# First Solution done
# Integral Done
# 2.1996627804145425e-11
# First Solution done
# Integral Done
# 2.2234424154191453e-11
# First Solution done
# Integral Done
# 2.2474791221194656e-11
# First Solution done
# Integral Done
# 2.2717756796101353e-11
# First Solution done
# Integral Done
# 2.2963348970295074e-11
# First Solution done
# Integral Done
# 2.3211596138842337e-11
# First Solution done
# Integral Done
# 2.346252700377783e-11
# First Solution done
# Integral Done
# 2.3716170577421265e-11
# First Solution done
# Integral Done
# 2.397255618573331e-11
# First Solution done
# Integral Done
# 2.4231713471704604e-11
# First Solution done
# Integral Done
# 2.449367239878351e-11
# First Solution done
# Integral Done
# 2.475846325434147e-11
# First Solution done
# Integral Done
# 2.5026116653173946e-11
# First Solution done
# Integral Done
# 2.52966635410394e-11
# First Solution done
# Integral Done
# 2.5570135198239035e-11
# First Solution done
# Integral Done
# 2.584656324323143e-11
# First Solution done
# Integral Done
# 2.61259796362894e-11
# First Solution done
# Integral Done
# 2.640841668319485e-11
# First Solution done
# Integral Done
# 2.6693907038974483e-11
# First Solution done
# Integral Done
# 2.6982483711674183e-11
# First Solution done
# Integral Done
# 2.7274180066176403e-11
# First Solution done
# Integral Done
# 2.7569029828057272e-11
# First Solution done
# Integral Done
# 2.78670670874859e-11
# First Solution done
# Integral Done
# 2.8168326303166397e-11
# First Solution done
# Integral Done
# 2.8472842306320964e-11
# First Solution done
# Integral Done
# 2.878065030471803e-11
# First Solution done
# Integral Done
# 2.909178588674199e-11
# First Solution done
# Integral Done
# 2.940628502550939e-11
# First Solution done
# Integral Done
# 2.972418408302551e-11
# First Solution done
# Integral Done
# 3.0045519814392065e-11
# First Solution done
# Integral Done
# 3.037032937205288e-11
# First Solution done
# Integral Done
# 3.0698650310092735e-11
# First Solution done
# Integral Done
# 3.103052058857698e-11
# First Solution done
# Integral Done
# 3.136597857794196e-11
# First Solution done
# Integral Done
# 3.1705063063430593e-11
# First Solution done
# Integral Done
# 3.204781324957688e-11
# First Solution done
# Integral Done
# 3.2394268764738654e-11
# First Solution done
# Integral Done
# 3.2744469665679036e-11
# First Solution done
# Integral Done
# 3.309845644219867e-11
# First Solution done
# Integral Done
# 3.3456270021815944e-11
# First Solution done
# Integral Done
# 3.381795177449986e-11
# First Solution done
# Integral Done
# 3.41835435174528e-11
# First Solution done
# Integral Done
# 3.455308751994573e-11
# First Solution done
# Integral Done
# 3.492662650820445e-11
# First Solution done
# Integral Done
# 3.530420367035038e-11
# First Solution done
# Integral Done
# 3.568586266139384e-11
# First Solution done
# Integral Done
# 3.607164760828111e-11
# First Solution done
# Integral Done
# 3.646160311499643e-11
# First Solution done
# Integral Done
# 3.685577426771896e-11
# First Solution done
# Integral Done
# 3.7254206640035916e-11
# First Solution done
# Integral Done
# 3.765694629821178e-11
# First Solution done
# Integral Done
# 3.806403980651312e-11
# First Solution done
# Integral Done
# 3.847553423259459e-11
# First Solution done
# Integral Done
# 3.889147715293884e-11
# First Solution done
# Integral Done
# 3.931191665835792e-11
# First Solution done
# Integral Done
# 3.9736901359554323e-11
# First Solution done
# Integral Done
# 4.016648039273923e-11
# First Solution done
# Integral Done
# 4.060070342531635e-11
# First Solution done
# Integral Done
# 4.1039620661622e-11
# First Solution done
# Integral Done
# 4.148328284873103e-11
# First Solution done
# Integral Done
# 4.193174128232293e-11
# First Solution done
# Integral Done
# 4.2385047812614394e-11
# First Solution done
# Integral Done
# 4.284325485035226e-11
# First Solution done
# Integral Done
# 4.330641537287481e-11
# First Solution done
# Integral Done
# 4.3774582930235894e-11
# First Solution done
# Integral Done
# 4.424781165139632e-11
# First Solution done
# Integral Done
# 4.4726156250482666e-11
# First Solution done
# Integral Done
# 4.5209672033113064e-11
# First Solution done
# Integral Done
# 4.5698414902791554e-11
# First Solution done
# Integral Done
# 4.619244136737194e-11
# First Solution done
# Integral Done
# 4.669180854559034e-11
# First Solution done
# Integral Done
# 4.719657417367016e-11
# First Solution done
# Integral Done
# 4.7706796611996266e-11
# First Solution done
# Integral Done
# 4.8222534851863797e-11
# First Solution done
# Integral Done
# 4.874384852229815e-11
# First Solution done
# Integral Done
# 4.9270797896949015e-11
# First Solution done
# Integral Done
# 4.980344390105972e-11
# First Solution done
# Integral Done
# 5.034184811851049e-11
# First Solution done
# Integral Done
# 5.088607279893979e-11
# First Solution done
# Integral Done
# 5.1436180864940804e-11
# First Solution done
# Integral Done
# 5.199223591933645e-11
# First Solution done
# Integral Done
# 5.2554302252533754e-11
# First Solution done
# Integral Done
# 5.312244484995717e-11
# First Solution done
# Integral Done
# 5.3696729399561024e-11
# First Solution done
# Integral Done
# 5.4277222299425654e-11
# First Solution done
# Integral Done
# 5.486399066543448e-11
# First Solution done
# Integral Done
# 5.545710233903335e-11
# First Solution done
# Integral Done
# 5.6056625895075314e-11
# First Solution done
# Integral Done
# 5.6662630649749726e-11
# First Solution done
# Integral Done
# 5.727518666859641e-11
# First Solution done
# Integral Done
# 5.7894364774608185e-11
# First Solution done
# Integral Done
# 5.852023655642067e-11
# First Solution done
# Integral Done
# 5.915287437658955e-11
# First Solution done
# Integral Done
# 5.979235137996047e-11
# First Solution done
# Integral Done
# 6.043874150212716e-11
# First Solution done
# Integral Done
# 6.109211947798426e-11
# First Solution done
# Integral Done
# 6.175256085037026e-11
# First Solution done
# Integral Done
# 6.242014197880909e-11
# First Solution done
# Integral Done
# 6.309494004834331e-11
# First Solution done
# Integral Done
# 6.377703307846759e-11
# First Solution done
# Integral Done
# 6.446649993215889e-11
# First Solution done
# Integral Done
# 6.516342032500931e-11
# First Solution done
# Integral Done
# 6.586787483445683e-11
# First Solution done
# Integral Done
# 6.657994490912353e-11
# First Solution done
# Integral Done
# 6.729971287825737e-11
# First Solution done
# Integral Done
# 6.80272619612845e-11
# First Solution done
# Integral Done
# 6.876267627746754e-11
# First Solution done
# Integral Done
# 6.950604085568088e-11
# First Solution done
# Integral Done
# 7.025744164430157e-11
# First Solution done
# Integral Done
# 7.101696552121705e-11
# First Solution done
# Integral Done
# 7.178470030396014e-11
# First Solution done
# Integral Done
# 7.256073475997008e-11
# First Solution done
# Integral Done
# 7.334515861698407e-11
# First Solution done
# Integral Done
# 7.413806257357202e-11
# First Solution done
# Integral Done
# 7.493953830981115e-11
# First Solution done
# Integral Done
# 7.57496784981166e-11
# First Solution done
# Integral Done
# 7.656857681422798e-11
# First Solution done
# Integral Done
# 7.739632794836966e-11
# First Solution done
# Integral Done
# 7.823302761658745e-11
# First Solution done
# Integral Done
# 7.907877257228004e-11
# First Solution done
# Integral Done
# 7.993366061793473e-11
# First Solution done
# Integral Done
# 8.07977906170787e-11
# First Solution done
# Integral Done
# 8.167126250648746e-11
# First Solution done
# Integral Done
# 8.255417730862265e-11
# First Solution done
# Integral Done
# 8.344663714437221e-11
# First Solution done
# Integral Done
# 8.434874524608575e-11
# First Solution done
# Integral Done
# 8.52606059709416e-11
# First Solution done
# Integral Done
# 8.6182324814679e-11
# First Solution done
# Integral Done
# 8.711400842572374e-11
# First Solution done
# Integral Done
# 8.805576461975092e-11
# First Solution done
# Integral Done
# 8.9007702394609e-11
# First Solution done
# ...
# Integral Done
# 0.001426989034912609
# First Solution done
# Integral Done
# 0.0014369126838054973
# First Solution done
# Integral Done
# 0.0014469050386927784
# First Solution done
# Integral Done
# 0.0014569665771106235
# First Solution done
# Integral Done
# 0.0014670977799100399
# First Solution done
# Integral Done
# 0.0014772991312796877
# First Solution done
# Integral Done
# 0.0014875711187689097
# First Solution done
# Integral Done
# 0.0014979142333108434
# First Solution done
# Integral Done
# 0.0015083289692457743
# First Solution done
# Integral Done
# 0.0015188158243446153
# First Solution done
# Integral Done
# 0.001529375299832541
# First Solution done
# Integral Done
# 0.0015400079004128482
# First Solution done
# Integral Done
# 0.0015507141342908993
# First Solution done
# Integral Done
# 0.0015614945131983188
# First Solution done
# Integral Done
# 0.0015723495524173105
# First Solution done
# Integral Done
# 0.001583279770805149
# First Solution done
# Integral Done
# 0.001594285690818894
# First Solution done
# Integral Done
# 0.001605367838540192
# First Solution done
# Integral Done
# 0.0016165267437003444
# First Solution done
# Integral Done
# 0.0016277629397054947
# First Solution done
# Integral Done
# 0.0016390769636620004
# First Solution done
# Integral Done
# 0.0016504693564020308
# First Solution done
# Integral Done
# 0.00166194066250926
# First Solution done
# Integral Done
# 0.0016734914303448303
# First Solution done
# Integral Done
# 0.0016851222120734454
# First Solution done
# Integral Done
# 0.0016968335636896445
# First Solution done
# Integral Done
# 0.0017086260450443207
# First Solution done
# Integral Done
# 0.0017205002198713297
# First Solution done
# Integral Done
# 0.0017324566558143844
# First Solution done
# Integral Done
# 0.0017444959244540756
# First Solution done
# Integral Done
# 0.0017566186013350902
# First Solution done
# Integral Done
# 0.001768825265993672
# First Solution done
# Integral Done
# 0.0017811165019851842
# First Solution done
# Integral Done
# 0.001793492896911959
# First Solution done
# Integral Done
# 0.0018059550424512848
# First Solution done
# Integral Done
# 0.0018185035343835961
# First Solution done
# Integral Done
# 0.0018311389726209067
# First Solution done
# Integral Done
# 0.0018438619612353665
# First Solution done
# Integral Done
# 0.0018566731084880864
# First Solution done
# Integral Done
# 0.0018695730268581392
# First Solution done
# Integral Done
# 0.0018825623330717398
# First Solution done
# Integral Done
# 0.0018956416481316985
# First Solution done
# Integral Done
# 0.0019088115973469873
# First Solution done
# Integral Done
# 0.0019220728103625962
# First Solution done
# Integral Done
# 0.0019354259211895606
# First Solution done
# Integral Done
# 0.0019488715682351807
# First Solution done
# Integral Done
# 0.001962410394333522
# First Solution done
# Integral Done
# 0.0019760430467760286
# First Solution done
# Integral Done
# 0.0019897701773424472
# First Solution done
# Integral Done
# 0.002003592442331912
# First Solution done
# Integral Done
# 0.002017510502594242
# First Solution done
# Integral Done
# 0.002031525023561524
# First Solution done
# Integral Done
# 0.002045636675279811
# First Solution done
# Integral Done
# 0.0020598461324411433
# First Solution done
# Integral Done
# 0.002074154074415737
# First Solution done
# Integral Done
# 0.0020885611852843942
# First Solution done
# Integral Done
# 0.0021030681538712005
# First Solution done
# Integral Done
# 0.002117675673776349
# First Solution done
# Integral Done
# 0.0021323844434092995
# First Solution done
# Integral Done
# 0.002147195166022109
# First Solution done
# Integral Done
# 0.0021621085497429827
# First Solution done
# Integral Done
# 0.002177125307610141
# First Solution done
# Integral Done
# 0.002192246157605802
# First Solution done
# Integral Done
# 0.002207471822690519
# First Solution done
# Integral Done
# 0.002222803030837688
# First Solution done
# Integral Done
# 0.0022382405150682926
# First Solution done
# Integral Done
# 0.0022537850134859744
# First Solution done
# Integral Done
# 0.002269437269312215
# First Solution done
# Integral Done
# 0.002285198030921896
# First Solution done
# Integral Done
# 0.0023010680518790296
# First Solution done
# Integral Done
# 0.0023170480909727414
# First Solution done
# Integral Done
# 0.0023331389122535867
# First Solution done
# Integral Done
# 0.0023493412850699785
# First Solution done
# Integral Done
# 0.0023656559841050157
# First Solution done
# Integral Done
# 0.002382083789413489
# First Solution done
# Integral Done
# 0.0023986254864591466
# First Solution done
# Integral Done
# 0.0024152818661522957
# First Solution done
# Integral Done
# 0.0024320537248875515
# First Solution done
# Integral Done
# 0.002448941864581969
# First Solution done
# Integral Done
# 0.002465947092713383
# First Solution done
# Integral Done
# 0.002483070222359008
# First Solution done
# Integral Done
# 0.0025003120722343936
# First Solution done
# Integral Done
# 0.002517673466732539
# First Solution done
# Integral Done
# 0.002535155235963405
# First Solution done
# Integral Done
# 0.0025527582157936356
# First Solution done
# Integral Done
# 0.0025704832478865747
# First Solution done
# Integral Done
# 0.0025883311797426423
# First Solution done
# Integral Done
# 0.002606302864739876
# First Solution done
# Integral Done
# 0.002624399162174908
# First Solution done
# Integral Done
# 0.0026426209373041553
# First Solution done
# Integral Done
# 0.0026609690613853243
# First Solution done
# Integral Done
# 0.0026794444117192993
# First Solution done
# Integral Done
# 0.0026980478716922174
# First Solution done
# Integral Done
# 0.002716780330817993
# First Solution done
# Integral Done
# 0.002735642684781092
# First Solution done
# Integral Done
# 0.0027546358354796304
# First Solution done
# Integral Done
# 0.0027737606910689014
# First Solution done
# Integral Done
# 0.002793018166005097
# First Solution done
# Integral Done
# 0.002812409181089533
# First Solution done
# Integral Done
# 0.0028319346635131333
# First Solution done
# Integral Done
# 0.002851595546901286
# First Solution done
# Integral Done
# 0.0028713927713591657
# First Solution done
# Integral Done
# 0.002891327283517286
# First Solution done
# Integral Done
# 0.0029114000365775988
# First Solution done
# Integral Done
# 0.0029316119903598976
# First Solution done
# Integral Done
# 0.002951964111348649
# First Solution done
# Integral Done
# 0.0029724573727403394
# First Solution done
# Integral Done
# 0.0029930927544910956
# First Solution done
# Integral Done
# 0.0030138712433649237
# First Solution done
# Integral Done
# 0.0030347938329822895
# First Solution done
# Integral Done
# 0.0030558615238693676
# First Solution done
# Integral Done
# 0.0030770753235073783
# First Solution done
# Integral Done
# 0.0030984362463832692
# First Solution done
# Integral Done
# 0.0031199453140397073
# First Solution done
# Integral Done
# 0.003141603555126839
# First Solution done
# Integral Done
# 0.0031634120054537555
# First Solution done
# Integral Done
# 0.0031853717080413276
# First Solution done
# Integral Done
# 0.0032074837131748813
# First Solution done
# Integral Done
# 0.0032297490784580062
# First Solution done
# Integral Done
# 0.0032521688688669347
# First Solution done
# Integral Done
# 0.0032747441568058777
# First Solution done
# Integral Done
# 0.003297476022162472
# First Solution done
# Integral Done
# 0.0033203655523647
# First Solution done
# Integral Done
# 0.0033434138424381847
# First Solution done
# Integral Done
# 0.0033666219950644425
# First Solution done
# Integral Done
# 0.0033899911206402905
# First Solution done
# Integral Done
# 0.0034135223373377307
# First Solution done
# Integral Done
# 0.00343721677116522
# First Solution done
# Integral Done
# 0.003461075556029462
# First Solution done
# Integral Done
# 0.00348509983379889
# First Solution done
# Integral Done
# 0.0035092907543677883
# First Solution done
# Integral Done
# 0.003533649475722019
# First Solution done
# Integral Done
# 0.00355817716400543
# First Solution done
# Integral Done
# 0.003582874993588174
# First Solution done
# Integral Done
# 0.0036077441471357445
# First Solution done
# Integral Done
# 0.003632785815679842
# First Solution done
# Integral Done
# 0.0036580011986910013
# First Solution done
# Integral Done
# 0.0036833915041520828
# First Solution done
# Integral Done
# 0.0037089579486336384
# First Solution done
# Integral Done
# 0.0037347017573713215
# First Solution done
# Integral Done
# 0.003760624164344733
# First Solution done
# Integral Done
# 0.0037867264123582294
# First Solution done
# Integral Done
# 0.003813009753123862
# First Solution done
# Integral Done
# 0.003839475447346073
# First Solution done
# Integral Done
# 0.0038661247648083324
# First Solution done
# Integral Done
# 0.0038929589844630646
# First Solution done
# Integral Done
# 0.003919979394522489
# First Solution done
# Integral Done
# 0.003947187292552613
# First Solution done
# Integral Done
# 0.003974583985569878
# First Solution done
# Integral Done
# 0.004002170790140074
# First Solution done
# Integral Done
# 0.004029949032480237
# First Solution done
# Integral Done
# 0.004057920048563077
# First Solution done
# Integral Done
# 0.004086085184224721
# First Solution done
# Integral Done
# 0.004114445795275363
# First Solution done
# Integral Done
# 0.004143003247612809
# First Solution done
# Integral Done
# 0.004171758917339631
# First Solution done
# Integral Done
# 0.004200714190884139
# First Solution done
# Integral Done
# 0.004229870465123612
# First Solution done
# Integral Done
# 0.0042592291475124664
# First Solution done
# Integral Done
# 0.0042887916562135316
# First Solution done
# Integral Done
# 0.0043185594202332514
# First Solution done
# Integral Done
# 0.004348533879561239
# First Solution done
# Integral Done
# 0.004378716485313309
# First Solution done
# Integral Done
# 0.004409108699879235
# First Solution done
# Integral Done
# 0.00443971199707517
# First Solution done
# Integral Done
# 0.004470527862299326
# First Solution done
# Integral Done
# 0.004501557792693595
# First Solution done
# Integral Done
# 0.004532803297309033
# First Solution done
# Integral Done
# 0.004564265897276487
# First Solution done
# Integral Done
# 0.004595947125982017
# First Solution done
# Integral Done
# 0.004627848529247309
# First Solution done
# Integral Done
# 0.004659971665515272
# First Solution done
# Integral Done
# 0.004692318106040959
# First Solution done
# Integral Done
# 0.004724889435087353
# First Solution done
# Integral Done
# 0.0047576872501270415
# First Solution done
# Integral Done
# 0.004790713162049035
# First Solution done
# Integral Done
# 0.004823968795371325
# First Solution done
# Integral Done
# 0.004857455788458806
# First Solution done
# Integral Done
# 0.004891175793747101
# First Solution done
# Integral Done
# 0.00492513047797195
# First Solution done
# Integral Done
# 0.004959321522404353
# First Solution done
# Integral Done
# 0.004993750623091658
# First Solution done
# Integral Done
# 0.005028419491104215
# First Solution done
# Integral Done
# 0.005063329852788098
# First Solution done
# Integral Done
# 0.0050984834500235375
# First Solution done
# Integral Done
# 0.005133882040489162
# First Solution done
# Integral Done
# 0.0051695273979322255
# First Solution done
# Integral Done
# 0.0052054213124443655
# First Solution done
# Integral Done
# 0.005241565590743347
# First Solution done
# Integral Done
# 0.00527796205646038
# First Solution done
# Integral Done
# 0.005314612550433053
# First Solution done
# Integral Done
# 0.005351518931003974
# First Solution done
# Integral Done
# 0.005388683074324611
# First Solution done
# Integral Done
# 0.0054261068746647755
# First Solution done
# Integral Done
# 0.005463792244727141
# First Solution done
# Integral Done
# 0.0055017411159669185
# First Solution done
# Integral Done
# 0.005539955438916598
# First Solution done
# Integral Done
# 0.005578437183515261
# First Solution done
# Integral Done
# 0.005617188339442663
# First Solution done
# Integral Done
# 0.005656210916457752
# First Solution done
# Integral Done
# 0.00569550694474122
# First Solution done
# Integral Done
# 0.005735078475242281
# First Solution done
# Integral Done
# 0.005774927580028891
# First Solution done
# Integral Done
# 0.005815056352641723
# First Solution done
# Integral Done
# 0.005855466908451184
# First Solution done
# Integral Done
# 0.005896161385017356
# First Solution done
# Integral Done
# 0.005937141942452644
# First Solution done
# Integral Done
# 0.005978410763786622
# First Solution done
# Integral Done
# 0.006019970055332872
# First Solution done
# Integral Done
# 0.006061822047057425
# First Solution done
# Integral Done
# 0.006103968992948418
# First Solution done
# Integral Done
# 0.006146413171386702
# First Solution done
# Integral Done
# 0.006189156885516794
# First Solution done
# Integral Done
# 0.0062322024636179895
# First Solution done
# Integral Done
# 0.006275552259475077
# First Solution done
# Integral Done
# 0.006319208652748232
# First Solution done
# Integral Done
# 0.006363174049341754
# First Solution done
# Integral Done
# 0.006407450881771084
# First Solution done
# Integral Done
# 0.006452041609527638
# First Solution done
# Integral Done
# 0.006496948719441049
# First Solution done
# Integral Done
# 0.006542174726038228
# First Solution done
# Integral Done
# 0.006587722171898964
# First Solution done
# Integral Done
# 0.006628467080331525
# First Solution done
# Integral Done
# 0.006669469648619583
# First Solution done
# Integral Done
# 0.006710731717792044
# First Solution done
# Integral Done
# 0.006752255147179305
# First Solution done
# Integral Done
# 0.006794041814596923
# First Solution done
# Integral Done
# 0.006836093616526187
# First Solution done
# Integral Done
# 0.0068784124682912
# First Solution done
# Integral Done
# 0.006921000304232326
# First Solution done
# Integral Done
# 0.00696385907787572
# First Solution done
# Integral Done
# 0.007006990762098734
# First Solution done
# Integral Done
# 0.007050397349291015
# First Solution done
# Integral Done
# 0.007094080851510993
# First Solution done
# Integral Done
# 0.007138043300637565
# First Solution done
# Integral Done
# 0.007182286748516841
# First Solution done
# Integral Done
# 0.007226813267103499
# First Solution done
# Integral Done
# 0.007271624948597004
# First Solution done
# Integral Done
# 0.00731672390557055
# First Solution done
# Integral Done
# 0.007362112271099186
# First Solution done
# Integral Done
# 0.007407792198873433
# First Solution done
# Integral Done
# 0.007453765863314496
# First Solution done
# Integral Done
# 0.007500035459678958
# First Solution done
# Integral Done
# 0.007546603204157811
# First Solution done
# Integral Done
# 0.007593471333968588
# First Solution done
# Integral Done
# 0.007640642107440533
# First Solution done
# Integral Done
# 0.007688117804092433
# First Solution done
# Integral Done
# 0.007735900724703331
# First Solution done
# Integral Done
# 0.007783993191375601
# First Solution done
# Integral Done
# 0.007832397547590438
# First Solution done
# Integral Done
# 0.007881116158255663
# First Solution done
# Integral Done
# 0.007930151409745461
# First Solution done
# Integral Done
# 0.00797950570993233
# First Solution done
# Integral Done
# 0.008029181488210775
# First Solution done
# Integral Done
# 0.00807918119551292
# First Solution done
# Integral Done
# 0.008129507304315815
# First Solution done
# Integral Done
# 0.0081801623086403
# First Solution done
# Integral Done
# 0.008231148724041638
# First Solution done
# Integral Done
# 0.008282469087591534
# First Solution done
# Integral Done
# 0.008334125957851799
# First Solution done
# Integral Done
# 0.008386121914839492
# First Solution done
# Integral Done
# 0.008438459559983388
# First Solution done
# Integral Done
# 0.008491141516072161
# First Solution done
# Integral Done
# 0.008544170427193914
# First Solution done
# Integral Done
# 0.008597548958667286
# First Solution done
# Integral Done
# 0.008651279796964204
# First Solution done
# Integral Done
# 0.008705365649624104
# First Solution done
# Integral Done
# 0.00875980924516002
# First Solution done
# Integral Done
# 0.008814613332956358
# First Solution done
# Integral Done
# 0.008869780683158574
# First Solution done
# Integral Done
# 0.008925314086554928
# First Solution done
# Integral Done
# 0.008981216354450153
# First Solution done
# Integral Done
# 0.009037490318531582
# First Solution done
# Integral Done
# 0.009094138830727575
# First Solution done
# Integral Done
# 0.009151164763058526
# First Solution done
# Integral Done
# 0.009208571007480688
# First Solution done
# Integral Done
# 0.009266360475722761
# First Solution done
# Integral Done
# 0.009324536099115809
# First Solution done
# Integral Done
# 0.009383100828416419
# First Solution done
# Integral Done
# 0.009442057633623444
# First Solution done
# Integral Done
# 0.009501409503788685
# First Solution done
# Integral Done
# 0.00956115944682142
# First Solution done
# Integral Done
# 0.009621310489287478
# First Solution done
# Integral Done
# 0.009681865676202805
# First Solution done
# Integral Done
# 0.009742828070821948
# First Solution done
# Integral Done
# 0.009804200754421774
# First Solution done
# Integral Done
# 0.009865986826080524
# First Solution done
# Integral Done
# 0.009928189402452822
# First Solution done
# Integral Done
# 0.009990811617540727
# First Solution done
# Integral Done

# %%
"""Calculate chi prime for matter """
solution_Chiprime_matter = np.zeros((len(kc_matter_IDE), 2)) #contains for every k; k, chi'(u_hc)
list_A_matter = np.zeros((len(kc_matter_IDE), 2)) #contains for every k; k, A

#Calculate chi(u), chi'(u)
def Bessel(x):
    return spherical_jn(2, x)
    
# Define the second-order ODE
def odefunc(t, Y, p):
    y, v = Y
    dydt = v
    dvdt = -2*p*v - y
    return [dydt, dvdt]


def odefuncIntegral(t, Y, p, o, b):
    y, v = Y
    dydt = v
    dvdt = -2*p*v - y - 24*b*p**2*o
    return [dydt, dvdt]

F_nu = F_nu_0/(1+a/a_eq)
U_Neutrino = np.where([tau==tau_dec])[1][0] #gives the index of tau = tau_dec


for loop in range(0,len(kc_matter_IDE)):
    print(kc_matter_IDE[loop])
    u = kc_matter_IDE[loop]*tau

    aprime_over_a = 1/kc_matter_IDE[loop]*(aprime/a)
    solution = []
    # Initial conditions
    chi_u_begin = 1
    dchi_du_begin = 0

    # Create an ODE solver
    solver_chi = ode(odefunc)
    solver_chi.set_integrator('dop853')  # You can choose a different method if needed

    # Set initial conditions
    solver_chi.set_initial_value([chi_u_begin, dchi_du_begin], t=0)
    
    # Solve the ODE
    
    q = 1
    solution.append([u[0], chi_u_begin, dchi_du_begin])
    while solver_chi.successful() and solver_chi.t < u[-1]: #and q<=len(u):
        solver_chi.set_f_params(aprime_over_a[q])
        solver_chi.integrate(u[q])
        solution.append([solver_chi.t, *solver_chi.y]) #contains time, chi, deriv of chi
        if not solver_chi.successful():
            print('error', q)
        q+=1

    # Extract the results
    solution = np.array(solution)
    
    #Now add the integral
    U_List = solution[:,0]
    Chi_Prime_List = solution[:,2]
    U_Size = np.size(solution[:,0])
    Integrant = np.zeros([U_Size,U_Size])

    Integral = np.zeros(U_Size)
    for i in range(U_Neutrino,U_Size):
        for j in range(U_Neutrino,i): 
            Integrant[i,j] = (U_List[j]-U_List[j-1])*Chi_Prime_List[j]*Bessel(U_List[i]-U_List[j])/((U_List[i]-U_List[j])**2)
        #print(i,U_Size)
    Integral = np.array(np.diag(np.cumsum(Integrant,axis = 1)))
    print('Integral Done')
    
    solution_Int = []

    # Create an ODE solver
    solver_chi_Int = ode(odefuncIntegral)
    solver_chi_Int.set_integrator('dop853')

    # Set initial conditions
    solver_chi_Int.set_initial_value([chi_u_begin, dchi_du_begin], t=0)
    
    # Solve the ODE
    q = 1
    solution_Int.append([u[0], chi_u_begin, dchi_du_begin, a[0]])
    while solver_chi_Int.successful() and solver_chi_Int.t < u[-1]: #and q<=len(u):
        solver_chi_Int.set_f_params(aprime_over_a[q], Integral[q], F_nu[q])
        solver_chi_Int.integrate(u[q])
        solution_Int.append([solver_chi_Int.t, *solver_chi_Int.y, a[q]]) #contains time, chi, deriv of chi
        if not solver_chi_Int.successful():
            print('error', q)
        q+=1

    # Extract the results
    solution_Int = np.array(solution_Int)
    solution_Chiprime_matter[loop,0], solution_Chiprime_matter[loop,1] = kc_matter_IDE[loop], solution_Int[-1,2]

    #Match to WKB solution
    def WKB(x, a, b):
        return a*np.sin(x+b)
    if kc_IDE[loop] < 1.5028390706082987e-15:
        a_u_latest = solution_Int[:,3][-10:]
        xdata = solution_Int[:,0][-10:] 
        ydata = solution_Int[:,1][-10:]*a_u_latest 
        initial_guess = [1,0.1]
    else:
        a_u_latest = solution_Int[:,3][-1000:]
        xdata = solution_Int[:,0][-1000:] 
        ydata = solution_Int[:,1][-1000:]*a_u_latest 
        initial_guess = [10**(-5),0.1]
    popt, pcov = curve_fit(WKB, xdata, ydata, p0 = initial_guess)

    #Use a WKB approximation to find chi'
    A = popt[0]
    list_A_matter[loop, 0], list_A_matter[loop,1] = kc_matter_IDE[loop], A

 
A_matter_SM_panda = pd.DataFrame(list(zip(np.transpose(list_A_matter[:,0]), np.transpose(list_A_matter[:,1]))), columns=['kc', "A"])
A_matter_SM_panda.to_csv('A_matter_SUSY_precise.csv', index=False)
ChiPrime_Matter_SM_panda = pd.DataFrame(list(zip(np.transpose(solution_Chiprime_matter[:,0]), np.transpose(solution_Chiprime_matter[:,1]))), columns=['kc', "chi_prime"])
ChiPrime_Matter_SM_panda.to_csv('ChiPrime_Matter_SUSY_precise.csv', index=False)
# Out:
# 2.0345707686406915e-18
# C:\Users\Annet\AppData\Local\Temp\ipykernel_17304\1589314201.py:31: RuntimeWarning: divide by zero encountered in divide
#   aprime_over_a = 1/kc_matter_IDE[loop]*(aprime/a)
# Integral Done
# 2.1273845323876854e-18
# Integral Done
# 2.2201982961346792e-18
# Integral Done
# 2.313012059881673e-18
# Integral Done
# 2.405825823628667e-18
# Integral Done
# 2.4986395873756613e-18
# Integral Done
# 2.5914533511226544e-18
# Integral Done
# 2.6842671148696487e-18
# Integral Done
# 2.777080878616643e-18
# Integral Done
# 2.8698946423636364e-18
# Integral Done
# 2.9627084061106295e-18
# Integral Done
# 3.0555221698576238e-18
# Integral Done
# 3.1483359336046177e-18
# Integral Done
# 3.241149697351611e-18
# Integral Done
# 3.3339634610986054e-18
# Integral Done
# 3.4267772248455997e-18
# Integral Done
# 3.5195909885925936e-18
# Integral Done
# 3.601989548473263e-18
# Integral Done
# 3.686317174172208e-18
# Integral Done
# 3.77261902782499e-18
# Integral Done
# 3.860941328876084e-18
# Integral Done
# 3.951331378831978e-18
# Integral Done
# 4.0438375865937055e-18
# Integral Done
# 4.138509494382595e-18
# Integral Done
# 4.2353978042728196e-18
# Integral Done
# 4.3345544053452016e-18
# Integral Done
# 4.436032401476701e-18
# Integral Done
# 4.539886139780489e-18
# Integral Done
# 4.6461712397118615e-18
# Integral Done
# 4.7549446228555456e-18
# Integral Done
# 4.8662645434103774e-18
# Integral Done
# 4.980190619387685e-18
# Integral Done
# 5.096783864539975e-18
# Integral Done
# 5.216106721037303e-18
# Integral Done
# 5.338223092908463e-18
# Integral Done
# 5.463198380265155e-18
# Integral Done
# 5.591099514327401e-18
# Integral Done
# 5.721994993268921e-18
# Integral Done
# 5.855954918901727e-18
# Integral Done
# 5.993051034219541e-18
# Integral Done
# 6.1333567618201516e-18
# Integral Done
# 6.276947243227321e-18
# Integral Done
# 6.4238993791332555e-18
# Integral Done
# 6.5742918705831135e-18
# Integral Done
# 6.728205261123943e-18
# Integral Done
# 6.885721979940139e-18
# Integral Done
# 7.046926385998872e-18
# Integral Done
# 7.211904813229015e-18
# Integral Done
# 7.38074561675777e-18
# Integral Done
# 7.553539220229743e-18
# Integral Done
# 7.73037816423385e-18
# Integral Done
# 7.911357155863973e-18
# Integral Done
# 8.096573119439756e-18
# Integral Done
# 8.28612524841516e-18
# Integral Done
# 8.480115058501951e-18
# Integral Done
# 8.678646442037045e-18
# Integral Done
# 8.88182572362263e-18
# Integral Done
# 9.089761717068916e-18
# Integral Done
# 9.302565783669963e-18
# Integral Done
# 9.520351891843887e-18
# Integral Done
# 9.743236678169253e-18
# Integral Done
# 9.971339509850511e-18
# Integral Done
# 1.0204782548645608e-17
# Integral Done
# 1.0443690816290655e-17
# Integral Done
# 1.0688192261455862e-17
# Integral Done
# 1.0938417828269191e-17
# Integral Done
# 1.1194501526444255e-17
# Integral Done
# 1.1456580503049948e-17
# Integral Done
# 1.1724795115960338e-17
# Integral Done
# 1.1999289009024134e-17
# Integral Done
# 1.2280209188993937e-17
# Integral Done
# 1.2567706104256603e-17
# Integral Done
# 1.2861933725406509e-17
# Integral Done
# 1.3163049627705684e-17
# Integral Done
# 1.3471215075473931e-17
# Integral Done
# 1.3786595108454888e-17
# Integral Done
# 1.4109358630203997e-17
# Integral Done
# 1.443967849854574e-17
# Integral Done
# 1.477773161814865e-17
# Integral Done
# 1.5123699035267593e-17
# Integral Done
# 1.5477766034704093e-17
# Integral Done
# 1.5840122239036734e-17
# Integral Done
# 1.621096171017435e-17
# Integral Done
# 1.659048305328733e-17
# Integral Done
# 1.6978889523171547e-17
# Integral Done
# 1.7376389133102572e-17
# Integral Done
# 1.7783194766238457e-17
# Integral Done
# 1.8199524289630445e-17
# Integral Done
# 1.8625600670902938e-17
# Integral Done
# 1.9061652097665038e-17
# Integral Done
# 1.950791209971772e-17
# Integral Done
# 1.9964619674122123e-17
# Integral Done
# 2.0432019413195422e-17
# Integral Done
# 2.0910361635504168e-17
# Integral Done
# 2.139990251992338e-17
# Integral Done
# 2.1900904242834792e-17
# Integral Done
# 2.241363511853682e-17
# Integral Done
# 2.2938369742941783e-17
# Integral Done
# 2.347538914063734e-17
# Integral Done
# 2.402498091539078e-17
# Integral Done
# 2.4587439404176823e-17
# Integral Done
# 2.5163065834811558e-17
# Integral Done
# 2.575216848727632e-17
# Integral Done
# 2.6355062858819305e-17
# Integral Done
# 2.6972071832921608e-17
# Integral Done
# 2.7603525852219287e-17
# Integral Done
# 2.824976309547386e-17
# Integral Done
# 2.891112965868578e-17
# Integral Done
# 2.958797974044815e-17
# Integral Done
# 3.0280675831639764e-17
# Integral Done
# 3.0989588909559154e-17
# Integral Done
# 3.1715098636603644e-17
# Integral Done
# 3.245759356359928e-17
# Integral Done
# 3.3217471337892065e-17
# Integral Done
# 3.399513891630979e-17
# Integral Done
# 3.479101278311025e-17
# Integral Done
# 3.560551917303159e-17
# Integral Done
# 3.6439094299564834e-17
# Integral Done
# 3.729218458857047e-17
# Integral Done
# 3.816524691736433e-17
# Integral Done
# 3.905874885940064e-17
# Integral Done
# 3.9973168934683963e-17
# Integral Done
# 4.090899686604303e-17
# Integral Done
# 4.1866733841404764e-17
# Integral Done
# 4.2846892782207853e-17
# Integral Done
# 4.384999861810134e-17
# Integral Done
# 4.487658856807325e-17
# Integral Done
# 4.592721242816138e-17
# Integral Done
# 4.7002432865899615e-17
# Integral Done
# 4.8102825721657837e-17
# Integral Done
# 4.92289803170361e-17
# Integral Done
# 5.038149977047964e-17
# Integral Done
# 5.156100132028211e-17
# Integral Done
# 5.276811665515112e-17
# Integral Done
# 5.4003492252512304e-17
# Integral Done
# 5.526778972473456e-17
# Integral Done
# 5.656168617345993e-17
# Integral Done
# 5.788587455222922e-17
# Integral Done
# 5.924106403759727e-17
# Integral Done
# 6.062798040893645e-17
# Integral Done
# 6.204736643713157e-17
# Integral Done
# 6.349998228237565e-17
# Integral Done
# 6.498660590127746e-17
# Integral Done
# 6.650803346350098e-17
# Integral Done
# 6.806507977815792e-17
# Integral Done
# 6.965857873018409e-17
# Integral Done
# 7.128938372693076e-17
# Integral Done
# 7.295836815521185e-17
# Integral Done
# 7.46664258490512e-17
# Integral Done
# 7.641447156838044e-17
# Integral Done
# 7.820344148894349e-17
# Integral Done
# 8.003429370367139e-17
# Integral Done
# 8.190800873579396e-17
# Integral Done
# 8.382559006396473e-17
# Integral Done
# 8.578806465967905e-17
# Integral Done
# 8.779648353727538e-17
# Integral Done
# 8.985192231681128e-17
# Integral Done
# 9.195548180011804e-17
# Integral Done
# 9.410828856034127e-17
# Integral Done
# 9.631149554528358e-17
# Integral Done
# 9.856628269487173e-17
# Integral Done
# 1.0087385757308113e-16
# Integral Done
# 1.0323545601465269e-16
# Integral Done
# 1.0565234278695171e-16
# Integral Done
# 1.0812581226732015e-16
# Integral Done
# 1.106571891362891e-16
# Integral Done
# 1.1324782908701788e-16
# Integral Done
# 1.1589911955134367e-16
# Integral Done
# 1.1861248044282812e-16
# Integral Done
# 1.2138936491720055e-16
# Integral Done
# 1.2423126015060269e-16
# Integral Done
# 1.2713968813605555e-16
# Integral Done
# 1.3011620649857086e-16
# Integral Done
# 1.3316240932934503e-16
# Integral Done
# 1.362799280394852e-16
# Integral Done
# 1.3947043223371975e-16
# Integral Done
# 1.427356306045647e-16
# Integral Done
# 1.460772718474235e-16
# Integral Done
# 1.4949714559711104e-16
# Integral Done
# 1.529970833863027e-16
# Integral Done
# 1.5657895962642095e-16
# Integral Done
# 1.6024469261148856e-16
# Integral Done
# 1.6399624554548113e-16
# Integral Done
# 1.6783562759373088e-16
# Integral Done
# 1.717648949589488e-16
# Integral Done
# 1.757861519824336e-16
# Integral Done
# 1.7990155227106454e-16
# Integral Done
# 1.841132998506776e-16
# Integral Done
# 1.884236503464436e-16
# Integral Done
# 1.9283491219088182e-16
# Integral Done
# 1.973494478601522e-16
# Integral Done
# 2.0196967513929532e-16
# Integral Done
# 2.0669806841708945e-16
# Integral Done
# 2.115371600112223e-16
# Integral Done
# 2.164895415244905e-16
# Integral Done
# 2.215578652327455e-16
# Integral Done
# 2.2674484550533496e-16
# Integral Done
# 2.320532602587992e-16
# Integral Done
# 2.3748595244459916e-16
# Integral Done
# 2.430458315716766e-16
# Integral Done
# 2.487358752646553e-16
# Integral Done
# 2.5455913085852787e-16
# Integral Done
# 2.6051871703067196e-16
# Integral Done
# 2.666178254710737e-16
# Integral Done
# 2.728597225916584e-16
# Integral Done
# 2.7924775127563395e-16
# Integral Done
# 2.8578533266779126e-16
# Integral Done
# 2.924759680067175e-16
# Integral Done
# 2.9932324049990427e-16
# Integral Done
# 3.0633081724275536e-16
# Integral Done
# 3.135024511825173e-16
# Integral Done
# 3.208419831281965e-16
# Integral Done
# 3.2835334380752215e-16
# Integral Done
# 3.3604055597207004e-16
# Integral Done
# 3.43907736551672e-16
# Integral Done
# 3.5195909885925937e-16
# Integral Done
# 3.557639815812564e-16
# Integral Done
# 3.5960999730017087e-16
# Integral Done
# 3.6349759068763997e-16
# Integral Done
# 3.6742721122246333e-16
# Integral Done
# 3.713993132425647e-16
# Integral Done
# 3.754143559975278e-16
# Integral Done
# 3.794728037016916e-16
# Integral Done
# 3.8357512558781995e-16
# Integral Done
# 3.877217959613591e-16
# Integral Done
# 3.919132942552702e-16
# Integral Done
# 3.961501050854659e-16
# Integral Done
# 4.0043271830683923e-16
# Integral Done
# 4.0476162906989724e-16
# Integral Done
# 4.091373378780151e-16
# Integral Done
# 4.1356035064529817e-16
# Integral Done
# 4.180311787550797e-16
# Integral Done
# 4.225503391190447e-16
# Integral Done
# 4.271183542369915e-16
# Integral Done
# 4.317357522572493e-16
# Integral Done
# 4.3640306703773445e-16
# Integral Done
# 4.411208382076805e-16
# Integral Done
# 4.458896112300276e-16
# Integral Done
# 4.507099374644845e-16
# Integral Done
# 4.555823742312834e-16
# Integral Done
# 4.605074848756094e-16
# Integral Done
# 4.654858388327383e-16
# Integral Done
# 4.705180116938739e-16
# Integral Done
# 4.756045852726931e-16
# Integral Done
# 4.8074614767262e-16
# Integral Done
# 4.859432933548166e-16
# Integral Done
# 4.911966232069183e-16
# Integral Done
# 4.965067446125052e-16
# Integral Done
# 5.018742715213253e-16
# Integral Done
# 5.072998245202841e-16
# Integral Done
# 5.127840309051892e-16
# Integral Done
# 5.183275247532838e-16
# Integral Done
# 5.23930946996555e-16
# Integral Done
# 5.295949454958348e-16
# Integral Done
# 5.353201751157123e-16
# Integral Done
# 5.4110729780024e-16
# Integral Done
# 5.469569826494728e-16
# Integral Done
# 5.528699059968281e-16
# Integral Done
# 5.588467514872771e-16
# Integral Done
# 5.648882101563959e-16
# Integral Done
# 5.709949805102529e-16
# Integral Done
# 5.771677686061767e-16
# Integral Done
# 5.834072881343873e-16
# Integral Done
# 5.897142605005067e-16
# Integral Done
# 5.960894149089778e-16
# Integral Done
# 6.025334884473621e-16
# Integral Done
# 6.090472261715706e-16
# Integral Done
# 6.156313811920025e-16
# Integral Done
# 6.222867147606151e-16
# Integral Done
# 6.290139963589473e-16
# Integral Done
# 6.35814003787076e-16
# Integral Done
# 6.426875232535542e-16
# Integral Done
# 6.496353494663064e-16
# Integral Done
# 6.566582857245087e-16
# Integral Done
# 6.637571440114739e-16
# Integral Done
# 6.709327450885221e-16
# Integral Done
# 6.781859185898859e-16
# Integral Done
# 6.85517503118622e-16
# Integral Done
# 6.929283463435774e-16
# Integral Done
# 7.004193050973942e-16
# Integral Done
# 7.079912454755684e-16
# Integral Done
# 7.156450429365978e-16
# Integral Done
# 7.233815824031958e-16
# Integral Done
# 7.312017583646004e-16
# Integral Done
# 7.391064749800058e-16
# Integral Done
# 7.470966461830868e-16
# Integral Done
# 7.551731957876793e-16
# Integral Done
# 7.633370575945788e-16
# Integral Done
# 7.715891754995149e-16
# Integral Done
# 7.799305036022802e-16
# Integral Done
# 7.883620063170358e-16
# Integral Done
# 7.968846584838268e-16
# Integral Done
# 8.054994454812862e-16
# Integral Done
# 8.142073633405586e-16
# Integral Done
# 8.23009418860472e-16
# Integral Done
# 8.319066297239287e-16
# Integral Done
# 8.409000246155829e-16
# Integral Done
# 8.49990643340761e-16
# Integral Done
# 8.591795369456955e-16
# Integral Done
# 8.684677678390412e-16
# Integral Done
# 8.778564099147035e-16
# Integral Done
# 8.873465486760101e-16
# Integral Done
# 8.96939281361213e-16
# Integral Done
# 9.066357170703416e-16
# Integral Done
# 9.16436976893451e-16
# Integral Done
# 9.26344194040224e-16
# Integral Done
# 9.363585139710068e-16
# Integral Done
# 9.46481094529232e-16
# Integral Done
# 9.567131060752986e-16
# Integral Done
# 9.670557316218834e-16
# Integral Done
# 9.77510166970713e-16
# Integral Done
# 9.880776208508314e-16
# Integral Done
# 9.98759315058349e-16
# Integral Done
# 1.0095564845976958e-15
# Integral Done
# 1.0204703778244277e-15
# Integral Done
# 1.031502256589541e-15
# Integral Done
# 1.0426533963853862e-15
# Integral Done
# 1.0539250864931187e-15
# Integral Done
# 1.0653186301317802e-15
# Integral Done
# 1.0768353446089694e-15
# Integral Done
# 1.0884765614731389e-15
# Integral Done
# 1.1002436266675662e-15
# Integral Done
# 1.1121379006859482e-15
# Integral Done
# 1.1241607587297182e-15
# Integral Done
# 1.1363135908670369e-15
# Integral Done
# 1.1485978021935054e-15
# Integral Done
# 1.1610148129946334e-15
# Integral Done
# 1.1735660589100356e-15
# Integral Done
# 1.1862529910994334e-15
# Integral Done
# 1.1990770764104297e-15
# Integral Done
# 1.2120397975480958e-15
# Integral Done
# 1.2251426532464158e-15
# Integral Done
# 1.23838715844156e-15
# Integral Done
# 1.2517748444470343e-15
# Integral Done
# 1.265307259130743e-15
# Integral Done
# 1.2789859670939355e-15
# Integral Done
# 1.2928125498521193e-15
# Integral Done
# 1.3067886060178962e-15
# Integral Done
# 1.3209157514858088e-15
# Integral Done
# 1.3351956196191593e-15
# Integral Done
# 1.3496298614388506e-15
# Integral Done
# 1.3642201458142927e-15
# Integral Done
# 1.3789681596563352e-15
# Integral Done
# 1.3938756081123236e-15
# Integral Done
# 1.4089442147632388e-15
# Integral Done
# 1.4241757218229672e-15
# Integral Done
# 1.4395718903397522e-15
# Integral Done
# 1.4551345003997827e-15
# Integral Done
# 1.4708653513330245e-15
# Integral Done
# 1.4867662619212459e-15
# Integral Done
# 1.5028390706082987e-15
# Integral Done
# 1.5190856357126926e-15
# Integral Done
# 1.535507835642431e-15
# Integral Done
# 1.5521075691122092e-15
# Integral Done
# 1.5688867553629351e-15
# Integral Done
# 1.5858473343836168e-15
# Integral Done
# 1.6029912671356869e-15
# Integral Done
# 1.6203205357797006e-15
# Integral Done
# 1.6378371439045281e-15
# Integral Done
# 1.6555431167590057e-15
# Integral Done
# 1.6734405014860772e-15
# Integral Done
# 1.6915313673595063e-15
# Integral Done
# 1.7098178060230958e-15
# Integral Done
# 1.7283019317325493e-15
# Integral Done
# 1.7469858815999004e-15
# Integral Done
# 1.7658718158406018e-15
# Integral Done
# 1.7849619180233025e-15
# Integral Done
# 1.80425839532229e-15
# Integral Done
# 1.8237634787726973e-15
# Integral Done
# 1.8434794235284477e-15
# Integral Done
# 1.8634085091229795e-15
# Integral Done
# 1.88355303973283e-15
# Integral Done
# 1.90391534444401e-15
# Integral Done
# 1.9244977775213174e-15
# Integral Done
# 1.945302718680524e-15
# Integral Done
# 1.9663325733635002e-15
# Integral Done
# 1.9875897730163608e-15
# Integral Done
# 2.009076775370552e-15
# Integral Done
# 2.0307960647270396e-15
# Integral Done
# 2.0527501522435303e-15
# Integral Done
# 2.074941576224791e-15
# Integral Done
# 2.0973729024161605e-15
# Integral Done
# 2.1200467243001613e-15
# Integral Done
# 2.142965663396382e-15
# Integral Done
# 2.1661323695645665e-15
# Integral Done
# 2.1895495213109704e-15
# Integral Done
# 2.2132198260980787e-15
# Integral Done
# 2.237146020657604e-15
# Integral Done
# 2.261330871306936e-15
# Integral Done
# 2.2857771742689653e-15
# Integral Done
# 2.3104877559953636e-15
# Integral Done
# 2.335465473493412e-15
# Integral Done
# 2.3607132146562825e-15
# Integral Done
# 2.386233898596974e-15
# Integral Done
# 2.4120304759857746e-15
# Integral Done
# 2.438105929391451e-15
# Integral Done
# 2.464463273626077e-15
# Integral Done
# 2.4911055560935793e-15
# Integral Done
# 2.5180358571421156e-15
# Integral Done
# 2.545257290420197e-15
# Integral Done
# 2.5727730032366727e-15
# Integral Done
# 2.600586176924653e-15
# Integral Done
# 2.6287000272092905e-15
# Integral Done
# 2.657117804579619e-15
# Integral Done
# 2.6858427946643292e-15
# Integral Done
# 2.7148783186116876e-15
# Integral Done
# 2.7442277334735057e-15
# Integral Done
# 2.773894432593262e-15
# Integral Done
# 2.8038818459984737e-15
# Integral Done
# 2.834193440797246e-15
# Integral Done
# 2.864832721579128e-15
# Integral Done
# 2.8958032308203432e-15
# Integral Done
# 2.9271085492933213e-15
# Integral Done
# 2.9587522964807513e-15
# Integral Done
# 2.9907381309940126e-15
# Integral Done
# 3.0230697509962206e-15
# Integral Done
# 3.055750894629786e-15
# Integral Done
# 3.088785340448598e-15
# Integral Done
# 3.1221769078549294e-15
# Integral Done
# 3.155929457541017e-15
# Integral Done
# 3.1900468919354075e-15
# Integral Done
# 3.2245331556541962e-15
# Integral Done
# 3.259392235957051e-15
# Integral Done
# 3.294628163208262e-15
# Integral Done
# 3.3302450113426793e-15
# Integral Done
# 3.3662468983367743e-15
# Integral Done
# 3.4026379866847473e-15
# Integral Done
# 3.439422483879761e-15
# Integral Done
# 3.476604642900446e-15
# Integral Done
# 3.5141887627026136e-15
# Integral Done
# 3.552179188716264e-15
# Integral Done
# 3.590580313348053e-15
# Integral Done
# 3.629396576489083e-15
# Integral Done
# 3.6686324660282914e-15
# Integral Done
# 3.708292518371279e-15
# Integral Done
# 3.748381318964849e-15
# Integral Done
# 3.788903502827162e-15
# Integral Done
# 3.829863755083593e-15
# Integral Done
# 3.871266811508474e-15
# Integral Done
# 3.913117459072618e-15
# Integral Done
# 3.9554205364967474e-15
# Integral Done
# 3.998180934811014e-15
# Integral Done
# 4.04140359792041e-15
# Integral Done
# 4.085093523176459e-15
# Integral Done
# 4.1292557619549255e-15
# Integral Done
# 4.173895420239911e-15
# Integral Done
# 4.219017659214183e-15
# Integral Done
# 4.264627695855865e-15
# Integral Done
# 4.310730803541685e-15
# Integral Done
# 4.3573323126566356e-15
# Integral Done
# 4.4044376112102506e-15
# Integral Done
# 4.452052145459619e-15
# Integral Done
# 4.500181420539003e-15
# Integral Done
# 4.548831001096405e-15
# Integral Done
# 4.598006511936879e-15
# Integral Done
# 4.647713638672916e-15
# Integral Done
# 4.6979581283817945e-15
# Integral Done
# 4.748745790270012e-15
# Integral Done
# 4.800082496344998e-15
# Integral Done
# 4.851974182094e-15
# Integral Done
# 4.904426847170313e-15
# Integral Done
# 4.957446556087009e-15
# Integral Done
# 5.01103943891804e-15
# Integral Done
# 5.065211692007065e-15
# Integral Done
# 5.119969578683783e-15
# Integral Done
# 5.175319429988167e-15
# Integral Done
# 5.2312676454024105e-15
# Integral Done
# 5.2878206935908135e-15
# Integral Done
# 5.344985113147722e-15
# Integral Done
# 5.402767513353502e-15
# Integral Done
# 5.46117457493865e-15
# Integral Done
# 5.520213050856293e-15
# Integral Done
# 5.579889767062868e-15
# Integral Done
# 5.640211623307419e-15
# Integral Done
# 5.7011855939292474e-15
# Integral Done
# 5.762818728664355e-15
# Integral Done
# 5.8251181534604975e-15
# Integral Done
# 5.888091071301034e-15
# Integral Done
# 5.951744763037803e-15
# Integral Done
# 6.016086588232893e-15
# Integral Done
# 6.081123986009498e-15
# Integral Done
# 6.146864475912125e-15
# Integral Done
# 6.213315658775869e-15
# Integral Done
# 6.280485217605342e-15
# Integral Done
# 6.348380918462846e-15
# Integral Done
# 6.417010611366378e-15
# Integral Done
# 6.486382231197204e-15
# Integral Done
# 6.556503798617231e-15
# Integral Done
# 6.627383420996427e-15
# Integral Done
# 6.6990292933501554e-15
# Integral Done
# 6.771449699286637e-15
# Integral Done
# 6.844653011964712e-15
# Integral Done
# 6.918647695061978e-15
# Integral Done
# 6.993442303753307e-15
# Integral Done
# 7.069045485699953e-15
# Integral Done
# 7.145465982049463e-15
# Integral Done
# 7.222712628446282e-15
# Integral Done
# 7.300794356053255e-15
# Integral Done
# 7.379720192584361e-15
# Integral Done
# 7.459499263348406e-15
# Integral Done
# 7.540140792304077e-15
# Integral Done
# 7.621654103126409e-15
# Integral Done
# 7.704048620284834e-15
# Integral Done
# 7.787333870132784e-15
# Integral Done
# 7.871519482009065e-15
# Integral Done
# 7.956615189351287e-15
# Integral Done
# 8.04263083082119e-15
# Integral Done
# 8.129576351442124e-15
# Integral Done
# 8.217461803748974e-15
# Integral Done
# 8.306297348950393e-15
# Integral Done
# 8.396093258103563e-15
# Integral Done
# 8.48685991330178e-15
# Integral Done
# 8.578607808874852e-15
# Integral Done
# 8.671347552602392e-15
# Integral Done
# 8.765089866940233e-15
# Integral Done
# 8.859845590260258e-15
# Integral Done
# 8.95562567810345e-15
# Integral Done
# 9.05244120444651e-15
# Integral Done
# 9.15030336298234e-15
# Integral Done
# 9.249223468414171e-15
# Integral Done
# 9.349212957763725e-15
# Integral Done
# 9.450283391693578e-15
# Integral Done
# 9.55244645584385e-15
# Integral Done
# 9.655713962183228e-15
# Integral Done
# 9.760097850374588e-15
# Integral Done

# %%
df_ChiPrime_Matter_SM_SUSY = pd.read_csv('ChiPrime_Matter_SUSY_precise.csv')
matter_k_SM_SUSY = df_ChiPrime_Matter_SM_SUSY['kc']
matter_chi_0_SM_SUSY = df_ChiPrime_Matter_SM_SUSY["chi_prime"]

df_ChiPrime_Rad_SM_SUSY = pd.read_csv('ChiPrime_Rad_SUSY_precise.csv')
rad_k_SM_SUSY = df_ChiPrime_Rad_SM_SUSY['kc']
rad_chi_0_SM_SUSY = df_ChiPrime_Rad_SM_SUSY["chi_prime"]

# %%
Omega_h_m_SUSY = delta_prim2/(12*a0**2*H0**2)*matter_chi_0_SM_SUSY**2*matter_k_SM_SUSY**2/10**(-10)
Omega_h_r_SUSY = delta_prim2/(12*a0**2*H0**2)*rad_chi_0_SM_SUSY**2*rad_k_SM_SUSY**2/10**(-10)
plt.plot(matter_k_SM_SUSY, Omega_h_m_SUSY, color='#1f77b4')
plt.plot(rad_k_SM_SUSY, Omega_h_r_SUSY, color='#1f77b4')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('kc (Hz)')
plt.ylabel(r'$\Omega_h(\tau_0)/10^{-10}$')
plt.title(r'$\Omega_h(\tau_0)$ Sm and SM+SUYS')
plt.xlim(5*10**(-19), 10**(-2))
plt.ylim(10**(-7), 10**(-2))
plt.show()

# %%
df_ChiPrime_Matter_SM = pd.read_csv('ChiPrime_Matter_SM_precise3.csv')
matter_k_SM = df_ChiPrime_Matter_SM['kc']
matter_chi_0_SM= df_ChiPrime_Matter_SM["chi_prime"]

df_ChiPrime_Rad_SM = pd.read_csv('ChiPrime_Rad_SM_precise.csv')
rad_k_SM = df_ChiPrime_Rad_SM['kc']
rad_chi_0_SM = df_ChiPrime_Rad_SM["chi_prime"]

# %%
Omega_h_m = delta_prim2/(12*a0**2*H0**2)*matter_chi_0_SM**2*matter_k_SM**2/10**(-10)
Omega_h_r = delta_prim2/(12*a0**2*H0**2)*rad_chi_0_SM**2*rad_k_SM**2/10**(-10)
plt.plot(matter_k_SM, Omega_h_m, color='#ff7f0e', label='SM')
plt.plot(rad_k_SM, Omega_h_r, color='#ff7f0e')
plt.plot(matter_k_SM_SUSY, Omega_h_m_SUSY, color='#1f77b4', label='SM+SUSY')
plt.plot(rad_k_SM_SUSY, Omega_h_r_SUSY, color='#1f77b4')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('kc (Hz)')
plt.ylabel(r'$\Omega_h(\tau_0)/10^{-10}$')
plt.title(r'$\Omega_h(\tau_0)/10^{-10}$ SM and SM+SUSY')
plt.xlim(5*10**(-19), 10**(-2))
plt.ylim(10**(-7), 10**(-2))
plt.legend()
#plt.savefig('GW_energy_density_SUSY_precise.png', bbox_inches='tight', dpi=450)
plt.show()

# %%
df_A_Matter_SM = pd.read_csv('A_matter_SM_precise3.csv')
A_matter_k_SM = df_A_Matter_SM['kc']
A_matter_chi_0_SM= df_A_Matter_SM["A"]

df_A_Rad_SM = pd.read_csv('A_rad_SM_precise.csv')
A_rad_k_SM = df_A_Rad_SM['kc']
A_rad_chi_0_SM = df_A_Rad_SM["A"]


df_A_Matter_SUSY = pd.read_csv('A_matter_SUSY_precise.csv')
A_matter_k_SUSY = df_A_Matter_SUSY['kc']
A_matter_chi_0_SUSY= df_A_Matter_SUSY["A"]

df_A_Rad_SUSY = pd.read_csv('A_rad_SUSY_precise.csv')
A_rad_k_SUSY = df_A_Rad_SUSY['kc']
A_rad_chi_0_SUSY = df_A_Rad_SUSY["A"]

# %%
plt.plot(A_matter_k_SM, A_matter_chi_0_SUSY**2/A_matter_chi_0_SM**2, color='#1f77b4')
plt.plot(A_rad_k_SM, A_rad_chi_0_SUSY**2/A_rad_chi_0_SM**2, color='#1f77b4')
plt.xscale('log')
plt.xlim(10**(-5), 0.01)

print(1-A_rad_chi_0_SUSY**2/A_rad_chi_0_SM**2)
# Out:
# 0       3.568179e-09
# 1       4.244599e-09
# 2      -2.655457e-08
# 3       4.312217e-09
# 4      -9.744858e-09
#             ...
# 6131    2.111981e-01
# 6132    2.112041e-01
# 6133    2.119534e-01
# 6134    2.118220e-01
# 6135    2.124089e-01
# Name: A, Length: 6136, dtype: float64

# %%
#plt.plot(matter_k_SM, Omega_h_m, color='#ff7f0e', label='SM')
#plt.plot(rad_k_SM, Omega_h_r, color='#ff7f0e')
#plt.plot(matter_k_SM_SUSY, Omega_h_m_SUSY, color='#1f77b4', label='SM+SUSY')
#plt.plot(rad_k_SM_SUSY, Omega_h_r_SUSY, color='#1f77b4')

plt.plot(A_matter_k_SM, delta_prim2/(12*a0**2*H0**2)*A_matter_chi_0_SM**2*A_matter_k_SM**2/10**(-10), color='#ff7f0e')
plt.plot(A_rad_k_SM, delta_prim2/(12*a0**2*H0**2)*A_rad_chi_0_SM**2*A_rad_k_SM**2/10**(-10), color='#ff7f0e')

plt.plot(A_matter_k_SUSY, delta_prim2/(12*a0**2*H0**2)*A_matter_chi_0_SUSY**2*A_matter_k_SUSY**2/10**(-10), color='#1f77b4')
plt.plot(A_rad_k_SUSY, delta_prim2/(12*a0**2*H0**2)*A_rad_chi_0_SUSY**2*A_rad_k_SUSY**2/10**(-10), color='#1f77b4')

plt.plot(A_matter_k_SM, A_matter_chi_0_SUSY/A_matter_chi_0_SM, color='#1f77b4')
plt.plot(A_rad_k_SM, A_rad_chi_0_SUSY/A_rad_chi_0_SM, color='#1f77b4')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('kc (Hz)')
plt.ylabel(r'$\Omega_h(\tau_0)/10^{-10}$')
plt.title(r'$\Omega_h(\tau_0)/10^{-10}$ SM and SM+SUSY')
plt.xlim(5*10**(-19), 10**(-2))
plt.ylim(10**(-7), 10**(-2))
plt.legend()
#plt.savefig('GW_energy_density_SUSY_full_correct.png', bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #Plot dof for the SM against the temperature
# df_SM_SUSY = pd.read_csv('dof_SM_SUSY.csv')
# plt.plot(df_SM_SUSY['temperature'], df_SM_SUSY['dof'], label='SM+SUSY')
# df_SM = pd.read_csv('dof_SM.csv')
# plt.plot(np.array(df_SM['temperature'])[:-700], np.array(df_SM['dof'])[:-700], linestyle='dashed', label="SM")
# plt.plot(np.logspace(7,10,100), 100*[np.array(df_SM['dof'])[-1]], color='#ff7f0e', linestyle='dashed')
# plt.xscale('log')
# plt.yscale('log')
# plt.xlabel('T (MeV)')
# plt.ylabel(r'$g_{\ast}$')
# plt.title('Number of effective relativisitic d.o.f SM and SUSY particles')
# plt.xlim(10**(-6), 10**10)
# plt.legend()
